# %% [markdown]
# # Demo for SPEL

# %%
# %tb
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Built-in modules
import re        # Regular expressions
import importlib # MUST BE USED TO RELOAD MODULES
import sys 

# Importing modules for SPEL functions 
import utilityFunctions as uf
import edit_files as ef 
import fortran_modules as fm 
from analyze_subroutines import Subroutine

# mod_config : system configuration and static variables. 
# Where E3SM is stored, where unit tests are stored, etc.
from mod_config import default_mods, unittests_dir, scripts_dir, spel_mods_dir
from mod_config import ELM_SRC, spel_output_dir, _bc
# Out:
# No traceback available to show.

# %% [markdown]
# SPEL needs a "casename" (what your unit-test is called) and a list of subroutines to create a unit-test for "sub_name_list" (examples are "LakeTemperature", "SoilTemperature", etc...)

# %%
# Define Unit Test parameters 
import os 
casename = "notebook_test"  # Name of the test case
case_dir = unittests_dir + casename # Directory to store the test case

# create directory for unit-test if it does not exist
if(not os.path.isdir(f"{case_dir}") ):
    print(f"Making case directory {case_dir}")
    if(not os.path.isdir(f"{unittests_dir}")):
        os.system(f"mkdir {unittests_dir}")
    os.system(f"mkdir {case_dir}")
    preprocess = True

# List of subroutines to be analyzed
# sub_name_list = ["SoilLittVertTransp","LakeTemperature","SoilTemperature"] 
sub_name_list = ["SoilTemperature"] 
sub_name_list = [sub.lower() for sub in sub_name_list]

# variables needed for Unit Test
main_sub_dict = {}  # Dictionary to store all Subroutines in files needed for Unit Test
mod_dict = {} 
subroutines = {k.lower():[] for k in sub_name_list} # Dictionary for User Specified Subroutines
# Out:
# Making case directory /home/mrgex/SPEL_Openacc/scripts/../unit-tests/notebook_test
# 0

# %% [markdown]
# 1st step for SPEL is determine which modules are needed for LakeTemperature and edit out the I/O, MPI, and other unneccessary modules. This must be somewhat tailored to ELM.
#
# Currently if I module is not present in the "components/elm/src/" (ELM_SRC) nor in the "share/utils" directories (SHR_SRC), then the module and any dependency on it is automatically removed.

# %%
 # List to hold all the modules needed for the unit test
needed_mods = [] 
for s in sub_name_list:
    # Get general info of the subroutine
    subroutines[s] = Subroutine(s,calltree=['elm_drv'])

    # Process by removing certain modules and syntax
    # so that a standalone unit test can be compiled.
    fn = subroutines[s].filepath
    mod_dict, file_list, main_sub_dict = ef.process_for_unit_test(
                fname=fn,
                case_dir=case_dir,
                mod_dict=mod_dict,
                mods=needed_mods,
                required_mods=default_mods,
                main_sub_dict=main_sub_dict,
                overwrite=True,
                verbose=False,
            )

    subroutines[s] = main_sub_dict[s]
# Out:
# Adding clumps to clump_type instances
# process_for_unit_test::new mods found ['SoilLittVertTranspMod.F90', 'shr_kind_mod.F90', 'elm_varctl.F90', 'elm_varcon.F90', 'decompMod.F90', 'CNDecompCascadeConType.F90', 'CanopyStateType.F90', 'CNStateType.F90', 'ColumnDataType.F90', 'timeinfoMod.F90', 'elm_varpar.F90', 'TridiagonalMod.F90', 'shr_const_mod.F90', 'domainMod.F90', 'landunit_varcon.F90', 'LandunitType.F90', 'ColumnType.F90', 'VegetationType.F90', 'topounit_varcon.F90', 'GridcellType.F90', 'CH4varcon.F90', 'pftvarcon.F90', 'soilorder_varcon.F90', 'column_varcon.F90', 'UrbanParamsType.F90', 'elm_varsur.F90']
# Adding filter to clumpfilter instances
# Adding filter_inactive_and_active to clumpfilter instances
# process_for_unit_test::new mods found ['CH4Mod.F90', 'EnergyFluxType.F90', 'LakeStateType.F90', 'SoilStateType.F90', 'SolarAbsorbedType.F90', 'VegetationDataType.F90', 'LakeCon.F90', 'QSatMod.F90', 'LakeTemperatureMod.F90', 'SharedParamsMod.F90', 'atm2lndType.F90', 'lnd2atmType.F90', 'SoilHydrologyType.F90', 'TopounitDataType.F90', 'shr_spfn_mod.F90', 'AnnualFluxDribbler.F90', 'FuncPedotransferMod.F90', 'RootBiophysMod.F90', 'domainLateralMod.F90', 'subgridAveMod.F90', 'SpeciesMod.F90', 'VegetationPropertiesType.F90']
# process_for_unit_test::new mods found ['LandunitDataType.F90', 'perfMod_GPU.F90', 'BandDiagonalMod.F90', 'SoilTemperatureMod.F90']

# %%
# Create dictionary containing all identified user defined types
# 'type-name' : 'DerivedType Object'
type_dict = {}
for modname, mod in mod_dict.items():
    for utype, dtype in mod.defined_types.items():
        type_dict[utype] = dtype

# %% [markdown]
# SPEL can print out a module tree showing how the modules are linked for the unit-test subroutines
# - The full tree can be pretty difficult to parse, having a cutoff depth is recommended.
# - Every module uses 'shr_kind_mod' so that could be suppressed as well.

# %%
modtree = fm.print_spel_module_dependencies(mod_dict=mod_dict,subs=subroutines)

# Print the module tree
arrow = "-->"
cutoff_depth = 10 # Only print modules up to this depth
suppress_mod_list = ['shr_kind_mod']
for m in modtree:
    depth = m['depth']
    modname = m['module']
    if(modname in suppress_mod_list):
        continue
    if(depth == 1):
        print(_bc.HEADER + arrow*depth + modname + _bc.ENDC)
    elif(depth <= cutoff_depth):
        print( arrow*depth + modname)
# Out:
# soillittverttranspmod
# -->elm_varctl
# -->elm_varcon
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->decompmod
# -->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->domainmod
# -->-->-->elm_varctl
# -->cndecompcascadecontype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->canopystatetype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->cnstatetype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->topounit_varcon
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->columndatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->soilorder_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->cndecompcascadecontype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->urbanparamstype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->-->elm_varsur
# -->timeinfomod
# -->elm_varpar
# -->-->elm_varctl
# -->tridiagonalmod
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# laketemperaturemod
# -->decompmod
# -->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->domainmod
# -->-->-->elm_varctl
# -->ch4mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->sharedparamsmod
# -->-->atm2lndtype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->canopystatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->energyfluxtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->annualfluxdribbler
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->shr_const_mod
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->lakestatetype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->lnd2atmtype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->soilhydrologytype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->sharedparamsmod
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->shr_const_mod
# -->-->-->shr_spfn_mod
# -->-->-->-->shr_const_mod
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->soilstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->sharedparamsmod
# -->-->-->funcpedotransfermod
# -->-->-->rootbiophysmod
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->domainlateralmod
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->topounitdatatype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->topounittype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columndatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->soilorder_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->cndecompcascadecontype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->urbanparamstype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varsur
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->vegetationdatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->subgridavemod
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->topounittype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->decompmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->speciesmod
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->vegetationpropertiestype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->columndatatype
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->ch4varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->soilorder_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->cnstatetype
# -->-->-->-->-->decompmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->landunittype
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->columntype
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->vegetationtype
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->gridcelltype
# -->-->-->-->-->-->landunit_varcon
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->cndecompcascadecontype
# -->-->-->-->-->decompmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->urbanparamstype
# -->-->-->-->-->decompmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->landunittype
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->gridcelltype
# -->-->-->-->-->-->landunit_varcon
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->column_varcon
# -->-->-->-->-->-->landunit_varcon
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varsur
# -->-->timeinfomod
# -->-->topounit_varcon
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->lakecon
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->tridiagonalmod
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->energyfluxtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->annualfluxdribbler
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->shr_const_mod
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->lakestatetype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->soilstatetype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->topounit_varcon
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->sharedparamsmod
# -->-->funcpedotransfermod
# -->-->rootbiophysmod
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->domainlateralmod
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->solarabsorbedtype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->landunit_varcon
# -->columntype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->columndatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->soilorder_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->cndecompcascadecontype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->urbanparamstype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->-->elm_varsur
# -->vegetationtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->vegetationdatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# ...
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->landunittype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->landunitdatatype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->columntype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->columndatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->soilorder_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->cndecompcascadecontype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->urbanparamstype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->-->elm_varsur
# -->vegetationtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->vegetationdatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->subgridavemod
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->topounittype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->speciesmod
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->vegetationpropertiestype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->columndatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->soilorder_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->cndecompcascadecontype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->urbanparamstype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varsur
# -->timeinfomod
# -->perfmod_gpu
# -->elm_varpar
# -->-->elm_varctl
# -->landunit_varcon
# -->column_varcon
# -->-->landunit_varcon
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->banddiagonalmod
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varctl

# %%
test_mod = mod_dict['soiltemperaturemod']
test_mod.print_module_info()
# Out:
# Module Name: soiltemperaturemod biogeophys/SoilTemperatureMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varctl-> iulog, use_petsc_thermal_model,
# use elm_varcon-> spval, cnfac, cpice, cpliq, denh2o, denice, tfrz, tkwat, tkice, tkair, thk_bedrock, hfus, grav, sb, hvap, capr,
# use urbanparamstype-> urbanparams_type,
# use atm2lndtype-> atm2lnd_type,
# use canopystatetype-> canopystate_type,
# use solarabsorbedtype-> solarabs_type,
# use soilstatetype-> soilstate_type,
# use energyfluxtype-> energyflux_type,
# use topounitdatatype-> top_af,
# use landunittype-> lun_pp,
# use landunitdatatype-> lun_es, lun_ef,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ef, col_ws, col_wf,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_ef, veg_wf,
# use timeinfomod-> all
# use perfmod_gpu-> all
# use elm_varpar-> nlevsno, nlevgrnd, nlevurb, nlevsoi, max_patch_per_col,
# use landunit_varcon-> istice, istice_mec, istsoil, istcrop, istwet,
# use column_varcon-> icol_roof, icol_sunwall, icol_shadewall, icol_road_perv, icol_road_imperv,
# use banddiagonalmod-> banddiagonal,
# Variables:
# integer default_thermal_model 0-D False
# integer petsc_thermal_model 0-D False
# integer thermal_model 0-D False
# real thin_sfclayer 0-D False
# User Types:

# %%
for s in sub_name_list:
    # Parsing means getting info on the variables read and written
    # to by the subroutine and any of its callees
    subroutines[s].parse_subroutine(dtype_dict=type_dict,
                                    main_sub_dict=main_sub_dict,verbose=True)
# Out:
# Resolving interface for tridiagonal
#  with args: ['bounds', '0', 'nlevdecomp+1', 'jtop', 'num_soilc', 'filter_soilc', 'a_tri', 'b_tri', 'c_tri', 'r_tri', 'conc_trcr']
# /home/mrgex/SPEL_Openacc/scripts/../../repo/E3SM/components/elm/src/biogeophys/TridiagonalMod.F90 14   interface Tridiagonal
# Couldn't match 0 to any known variable -- assuming xx type
# Couldn't match nlevdecomp+1 to any known variable -- assuming xx type
# tridiagonal_sr:: 1 Optional arguments found
# bounds matches bounds
# 0 matches lbj
# nlevdecomp+1 matches ubj
# jtop matches jtop
# num_soilc matches numf
# filter_soilc matches filter
# a_tri matches a
# b_tri matches b
# c_tri matches c
# r_tri matches r
# conc_trcr matches u
# resolve_interface::Subroutine is tridiagonal_sr
# _preprocess_file::New child sub name is: tridiagonal_sr
# _preprocess_file::Finished analyzing for soillittverttransp
# Resolving interface for tridiagonal
#  with args: ['bounds', '-nlevsno + 1', 'nlevlak + nlevgrnd', 'jtop', 'num_lakec', 'filter_lakec', 'a', 'b', 'c1', 'r', 'tx']
# /home/mrgex/SPEL_Openacc/scripts/../../repo/E3SM/components/elm/src/biogeophys/TridiagonalMod.F90 14   interface Tridiagonal
# Couldn't match -nlevsno + 1 to any known variable -- assuming xx type
# Couldn't match nlevlak + nlevgrnd to any known variable -- assuming xx type
# tridiagonal_sr:: 1 Optional arguments found
# bounds matches bounds
# -nlevsno + 1 matches lbj
# nlevlak + nlevgrnd matches ubj
# jtop matches jtop
# num_lakec matches numf
# filter_lakec matches filter
# a matches a
# b matches b
# c1 matches c
# r matches r
# tx matches u
# resolve_interface::Subroutine is tridiagonal_sr
# _preprocess_file::New child sub name is: tridiagonal_sr
# _preprocess_file::Finished analyzing for laketemperature
# _preprocess_file::Finished analyzing for soiltemperature

# %%
read_types  = [] 
write_types = []
func_name = "Notebook"
for s in sub_name_list:
    subroutines[s].child_subroutines_analysis(dtype_dict=type_dict,
                                        main_sub_dict=main_sub_dict,verbose=True)

    print(_bc.OKGREEN + f"Derived Type Analysis for {subroutines[s].name}")
    print(f"{func_name}::Read-Only")
    for key in subroutines[s].elmtype_r.keys():
        print(key, subroutines[s].elmtype_r[key])
    print(f"{func_name}::Write-Only")
    for key in subroutines[s].elmtype_w.keys():
        print(key, subroutines[s].elmtype_w[key])
    print(f"{func_name}::Read-Write")
    for key in subroutines[s].elmtype_rw.keys():
        print(key, subroutines[s].elmtype_rw[key])
    print(_bc.ENDC)

    for key in list(subroutines[s].elmtype_r.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_r[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        read_types.append(key)

    for key in list(subroutines[s].elmtype_w.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_w[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        write_types.append(key)

    for key in list(subroutines[s].elmtype_rw.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_rw[key]
            continue
        write_types.append(key)
# Out:
# Analyzing child subroutine: tridiagonal_sr
# _preprocess_file::Finished analyzing for tridiagonal_sr
# Derived Type Analysis for soillittverttransp
# Notebook::Read-Only
# soillittverttranspparamsinst%som_diffus r
# soillittverttranspparamsinst%cryoturb_diffusion_k r
# soillittverttranspparamsinst%max_altdepth_cryoturbation r
# canopystate_vars%altmax_col r
# canopystate_vars%altmax_lastyear_col r
# decomp_cascade_con%spinup_factor r
# decomp_cascade_con%is_cwd r
# cnstate_vars%scalaravg_col r
# col_cf%decomp_cpools_sourcesink r
# col_nf%decomp_npools_sourcesink r
# col_pf%decomp_ppools_sourcesink r
# c13_col_cf%decomp_cpools_sourcesink r
# c14_col_cf%decomp_cpools_sourcesink r
# Notebook::Write-Only
# Notebook::Read-Write
# cnstate_vars%som_diffus_coef_col rw
# cnstate_vars%som_adv_coef_col rw
# col_cs%decomp_cpools_vr rw
# col_ns%decomp_npools_vr rw
# col_ps%decomp_ppools_vr rw
# c13_col_cs%decomp_cpools_vr rw
# c14_col_cs%decomp_cpools_vr rw
# col_cf%decomp_cpools_transport_tendency rw
# col_nf%decomp_npools_transport_tendency rw
# col_pf%decomp_ppools_transport_tendency rw
# c13_col_cf%decomp_cpools_transport_tendency rw
# c14_col_cf%decomp_cpools_transport_tendency rw
#
# Analyzing child subroutine: soilthermprop_lake
# _preprocess_file::Finished analyzing for soilthermprop_lake
# Analyzing child subroutine: tridiagonal_sr
# _preprocess_file::Finished analyzing for tridiagonal_sr
# Analyzing child subroutine: phasechange_lake
# _preprocess_file::Finished analyzing for phasechange_lake
# Derived Type Analysis for laketemperature
# Notebook::Read-Only
# bounds%endc r
# bounds%begc r
# col_pp%snl r
# veg_pp%column r
# solarabs_vars%fsds_nir_d_patch r
# solarabs_vars%fsds_nir_i_patch r
# solarabs_vars%fsr_nir_d_patch r
# solarabs_vars%fsr_nir_i_patch r
# solarabs_vars%sabg_patch r
# col_pp%z_lake r
# lakestate_vars%ws_col r
# lakestate_vars%ks_col r
# col_es%t_grnd r
# col_pp%lakedepth r
# lakestate_vars%etal_col r
# col_pp%dz_lake r
# solarabs_vars%sabg_lyr_patch r
# col_pp%z r
# col_pp%dz r
# lakestate_vars%lake_raw_col r
# soilstate_vars%tksatu_col r
# soilstate_vars%tkmg_col r
# soilstate_vars%watsat_col r
# soilstate_vars%tkdry_col r
# col_pp%zi r
# soilstate_vars%csol_col r
# Notebook::Write-Only
# col_ws%frac_iceold w
# lakestate_vars%savedtke1_col w
# col_ef%eflx_snomelt w
# col_ef%imelt w
# Notebook::Read-Write
# col_es%hc_soisno rw
# col_es%hc_soi rw
# lakestate_vars%lakeresist_col rw
# veg_ef%eflx_gnet rw
# lakestate_vars%betaprime_col rw
# lakestate_vars%lake_icefrac_col rw
# col_es%t_lake rw
# col_es%t_soisno rw
# ch4_vars%grnd_ch4_cond_col rw
# col_ef%errsoi rw
# veg_ef%eflx_sh_tot rw
# veg_ef%eflx_sh_grnd rw
# veg_ef%eflx_soil_grnd rw
# lakestate_vars%lake_icethick_col rw
# col_wf%qflx_snomelt rw
# col_wf%qflx_snow_melt rw
# col_wf%qflx_snofrz_lyr rw
# col_ws%h2osno rw
# col_ws%snow_depth rw
# col_ws%h2osoi_ice rw
# col_ws%h2osoi_liq rw
# col_wf%qflx_snofrz rw
#
# Analyzing child subroutine: soilthermprop
# _preprocess_file::Finished analyzing for soilthermprop
# Analyzing child subroutine: computegroundheatfluxandderiv
# _preprocess_file::Finished analyzing for computegroundheatfluxandderiv
# Analyzing child subroutine: computeheatdifffluxandfactor
# _preprocess_file::Finished analyzing for computeheatdifffluxandfactor
# Analyzing child subroutine: solvetemperature
# _preprocess_file::Finished analyzing for solvetemperature
# Analyzing child subroutine: setrhsvec
# _preprocess_file::Finished analyzing for setrhsvec
# Analyzing child subroutine: setrhsvec_snow
# _preprocess_file::Finished analyzing for setrhsvec_snow
# Analyzing child subroutine: setrhsvec_snowurban
# _preprocess_file::Finished analyzing for setrhsvec_snowurban
# Analyzing child subroutine: setrhsvec_snowurbannonroad
# _preprocess_file::Finished analyzing for setrhsvec_snowurbannonroad
# Analyzing child subroutine: setrhsvec_snowurbanroad
# _preprocess_file::Finished analyzing for setrhsvec_snowurbanroad
# Analyzing child subroutine: setrhsvec_snownonurban
# _preprocess_file::Finished analyzing for setrhsvec_snownonurban
# Analyzing child subroutine: setrhsvec_standingsurfacewater
# _preprocess_file::Finished analyzing for setrhsvec_standingsurfacewater
# Analyzing child subroutine: setrhsvec_soil
# _preprocess_file::Finished analyzing for setrhsvec_soil
# Analyzing child subroutine: setrhsvec_soilurban
# _preprocess_file::Finished analyzing for setrhsvec_soilurban
# Analyzing child subroutine: setrhsvec_soilurbannonroad
# _preprocess_file::Finished analyzing for setrhsvec_soilurbannonroad
# Analyzing child subroutine: setrhsvec_soilurbanroad
# _preprocess_file::Finished analyzing for setrhsvec_soilurbanroad
# Analyzing child subroutine: setrhsvec_soilnonurban
# _preprocess_file::Finished analyzing for setrhsvec_soilnonurban
# Analyzing child subroutine: setrhsvec_soil_standingsurfacewater
# _preprocess_file::Finished analyzing for setrhsvec_soil_standingsurfacewater
# Analyzing child subroutine: setmatrix
# _preprocess_file::Finished analyzing for setmatrix
# Analyzing child subroutine: setmatrix_snow
# _preprocess_file::Finished analyzing for setmatrix_snow
# Analyzing child subroutine: setmatrix_snowurban
# _preprocess_file::Finished analyzing for setmatrix_snowurban
# Analyzing child subroutine: setmatrix_snowurbannonroad
# _preprocess_file::Finished analyzing for setmatrix_snowurbannonroad
# Analyzing child subroutine: setmatrix_snowurbanroad
# _preprocess_file::Finished analyzing for setmatrix_snowurbanroad
# Analyzing child subroutine: setmatrix_snownonurban
# _preprocess_file::Finished analyzing for setmatrix_snownonurban
# Analyzing child subroutine: setmatrix_snow_soil
# _preprocess_file::Finished analyzing for setmatrix_snow_soil
# Analyzing child subroutine: setmatrix_snow_soilurban
# _preprocess_file::Finished analyzing for setmatrix_snow_soilurban
# Analyzing child subroutine: setmatrix_snow_soilurbannonroad
# _preprocess_file::Finished analyzing for setmatrix_snow_soilurbannonroad
# Analyzing child subroutine: setmatrix_snow_soilurbanroad
# _preprocess_file::Finished analyzing for setmatrix_snow_soilurbanroad
# Analyzing child subroutine: setmatrix_snow_soilnonurban
# _preprocess_file::Finished analyzing for setmatrix_snow_soilnonurban
# Analyzing child subroutine: setmatrix_soil
# _preprocess_file::Finished analyzing for setmatrix_soil
# Analyzing child subroutine: setmatrix_soilurban
# _preprocess_file::Finished analyzing for setmatrix_soilurban
# Analyzing child subroutine: setmatrix_soilurbannonroad
# _preprocess_file::Finished analyzing for setmatrix_soilurbannonroad
# Analyzing child subroutine: setmatrix_soilurbanroad
# _preprocess_file::Finished analyzing for setmatrix_soilurbanroad
# Analyzing child subroutine: setmatrix_soilnonurban
# _preprocess_file::Finished analyzing for setmatrix_soilnonurban
# Analyzing child subroutine: setmatrix_soil_snow
# _preprocess_file::Finished analyzing for setmatrix_soil_snow
# Analyzing child subroutine: setmatrix_soil_snowurban
# _preprocess_file::Finished analyzing for setmatrix_soil_snowurban
# Analyzing child subroutine: setmatrix_soil_snowurbannonroad
# _preprocess_file::Finished analyzing for setmatrix_soil_snowurbannonroad
# Analyzing child subroutine: setmatrix_soil_snowurbanroad
# _preprocess_file::Finished analyzing for setmatrix_soil_snowurbanroad
# Analyzing child subroutine: setmatrix_soil_snownonurban
# _preprocess_file::Finished analyzing for setmatrix_soil_snownonurban
# Analyzing child subroutine: setmatrix_standingsurfacewater
# _preprocess_file::Finished analyzing for setmatrix_standingsurfacewater
# Analyzing child subroutine: setmatrix_standingsurfacewater_soil
# _preprocess_file::Finished analyzing for setmatrix_standingsurfacewater_soil
# Analyzing child subroutine: setmatrix_soil_standingsurfacewater
# _preprocess_file::Finished analyzing for setmatrix_soil_standingsurfacewater
# Analyzing child subroutine: assemblematrixfromsubmatrices
# _preprocess_file::Finished analyzing for assemblematrixfromsubmatrices
# Analyzing child subroutine: banddiagonal
# Warning: dgbsv not in main_sub_dict.
# Could be library function?
# Creating Subroutine dgbsv in lib.F90 L-999--999
# _preprocess_file::Finished analyzing for banddiagonal
# child_subroutines_analysis:: dgbsv is a library function -- Skipping.
# Analyzing child subroutine: phasechangeh2osfc
# _preprocess_file::Finished analyzing for phasechangeh2osfc
# Analyzing child subroutine: phasechange_beta
# _preprocess_file::Finished analyzing for phasechange_beta
# Derived Type Analysis for soiltemperature
# Notebook::Read-Only
# lun_pp%urbpoi r
# urbanparams_vars%t_building_max r
# urbanparams_vars%t_building_min r
# col_pp%snl r
# col_pp%itype r
# col_pp%landunit r
# bounds%endl r
# bounds%begl r
# bounds%begc r
# bounds%endc r
# col_ws%frac_h2osfc r
# col_pp%z r
# col_pp%zi r
# col_es%t_ssbef r
# col_ws%frac_sno_eff r
# lun_pp%itype r
# col_pp%nlevbed r
# urbanparams_vars%tk_wall r
# urbanparams_vars%tk_roof r
# urbanparams_vars%nlev_improad r
# urbanparams_vars%tk_improad r
# col_pp%dz r
# soilstate_vars%watsat_col r
# soilstate_vars%tkmg_col r
# soilstate_vars%tkdry_col r
# urbanparams_vars%cv_wall r
# urbanparams_vars%cv_roof r
# urbanparams_vars%cv_improad r
# soilstate_vars%csol_col r
# col_es%emg r
# col_pp%npfts r
# col_pp%pfti r
# veg_pp%landunit r
# veg_pp%topounit r
# veg_pp%gridcell r
# veg_pp%active r
# solarabs_vars%sabg_patch r
# veg_ef%dlrad r
# canopystate_vars%frac_veg_nosno_patch r
# top_af%lwrad r
# veg_ef%eflx_sh_grnd r
# veg_wf%qflx_evap_soi r
# col_ef%htvp r
# solarabs_vars%sabg_snow_patch r
# solarabs_vars%sabg_soil_patch r
# veg_ef%eflx_sh_snow r
# veg_wf%qflx_ev_snow r
# veg_ef%eflx_sh_soil r
# veg_wf%qflx_ev_soil r
# veg_ef%eflx_sh_h2osfc r
# veg_wf%qflx_ev_h2osfc r
# lun_pp%wtlunit_roof r
# lun_ef%eflx_wasteheat r
# lun_ef%eflx_heat_from_ac r
# lun_ef%eflx_traffic r
# veg_ef%eflx_lwrad_net r
# veg_wf%qflx_tran_veg r
# veg_ef%cgrnd r
# veg_pp%wtcol r
# solarabs_vars%sabg_lyr_patch r
# col_ef%eflx_bot r
# col_es%fact r
# soilstate_vars%sucsat_col r
# soilstate_vars%bsw_col r
# Notebook::Write-Only
# col_ef%eflx_urban_ac w
# col_ef%eflx_urban_heat w
# col_ef%xmf_h2osfc w
# col_ef%eflx_fgr12 w
# col_ef%eflx_fgr w
# solarabs_vars%sabg_chk_patch w
# veg_ef%eflx_anthro w
# col_wf%qflx_h2osfc_to_ice w
# col_ef%eflx_h2osfc_to_snow w
# col_wf%qflx_snow_melt w
# col_ef%eflx_snomelt_u w
# col_ef%eflx_snomelt_r w
# Notebook::Read-Write
# lun_es%t_building rw
# col_es%t_soisno rw
# col_es%t_h2osfc rw
# col_ef%eflx_building_heat rw
# col_es%hc_soisno rw
# col_es%hc_soi rw
# soilstate_vars%thk_col rw
# col_ws%bw rw
# col_es%t_grnd rw
# veg_ef%eflx_gnet rw
# veg_ef%eflx_wasteheat rw
# veg_ef%eflx_heat_from_ac rw
# veg_ef%eflx_traffic rw
# veg_ef%dgnetdt rw
# col_es%c_h2osfc rw
# col_ws%h2osfc rw
# col_ws%snow_depth rw
# col_ws%h2osno rw
# col_ws%int_snow rw
# col_wf%qflx_snomelt rw
# col_ef%xmf rw
# col_wf%qflx_snofrz_lyr rw
# col_wf%qflx_snofrz rw
# col_wf%qflx_glcice_melt rw
# col_ef%imelt rw
# col_ws%h2osoi_ice rw
# col_ws%h2osoi_liq rw
# col_wf%qflx_glcice rw
# col_ef%eflx_snomelt rw

# %%
# Make sure physical properties types are read/written:
list_pp = ['veg_pp','lun_pp','col_pp','grc_pp','top_pp']

print("read_types:",read_types)
print("write_types:",write_types)

aggregated_elmtypes_list = []
for x in read_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)    
for x in write_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)

# for l in list_pp:
#     aggregated_elmtypes_list.append(l)
print("list of global vars:",aggregated_elmtypes_list)
# Out:
# read_types: ['soillittverttranspparamsinst%som_diffus', 'soillittverttranspparamsinst%cryoturb_diffusion_k', 'soillittverttranspparamsinst%max_altdepth_cryoturbation', 'canopystate_vars%altmax_col', 'canopystate_vars%altmax_lastyear_col', 'decomp_cascade_con%spinup_factor', 'decomp_cascade_con%is_cwd', 'cnstate_vars%scalaravg_col', 'col_cf%decomp_cpools_sourcesink', 'col_nf%decomp_npools_sourcesink', 'col_pf%decomp_ppools_sourcesink', 'bounds%endc', 'bounds%begc', 'col_pp%snl', 'veg_pp%column', 'solarabs_vars%fsds_nir_d_patch', 'solarabs_vars%fsds_nir_i_patch', 'solarabs_vars%fsr_nir_d_patch', 'solarabs_vars%fsr_nir_i_patch', 'solarabs_vars%sabg_patch', 'col_pp%z_lake', 'lakestate_vars%ws_col', 'lakestate_vars%ks_col', 'col_es%t_grnd', 'col_pp%lakedepth', 'lakestate_vars%etal_col', 'col_pp%dz_lake', 'solarabs_vars%sabg_lyr_patch', 'col_pp%z', 'col_pp%dz', 'lakestate_vars%lake_raw_col', 'soilstate_vars%tksatu_col', 'soilstate_vars%tkmg_col', 'soilstate_vars%watsat_col', 'soilstate_vars%tkdry_col', 'col_pp%zi', 'soilstate_vars%csol_col', 'lun_pp%urbpoi', 'urbanparams_vars%t_building_max', 'urbanparams_vars%t_building_min', 'col_pp%snl', 'col_pp%itype', 'col_pp%landunit', 'bounds%endl', 'bounds%begl', 'bounds%begc', 'bounds%endc', 'col_ws%frac_h2osfc', 'col_pp%z', 'col_pp%zi', 'col_es%t_ssbef', 'col_ws%frac_sno_eff', 'lun_pp%itype', 'col_pp%nlevbed', 'urbanparams_vars%tk_wall', 'urbanparams_vars%tk_roof', 'urbanparams_vars%nlev_improad', 'urbanparams_vars%tk_improad', 'col_pp%dz', 'soilstate_vars%watsat_col', 'soilstate_vars%tkmg_col', 'soilstate_vars%tkdry_col', 'urbanparams_vars%cv_wall', 'urbanparams_vars%cv_roof', 'urbanparams_vars%cv_improad', 'soilstate_vars%csol_col', 'col_es%emg', 'col_pp%npfts', 'col_pp%pfti', 'veg_pp%landunit', 'veg_pp%topounit', 'veg_pp%gridcell', 'veg_pp%active', 'solarabs_vars%sabg_patch', 'veg_ef%dlrad', 'canopystate_vars%frac_veg_nosno_patch', 'top_af%lwrad', 'veg_ef%eflx_sh_grnd', 'veg_wf%qflx_evap_soi', 'col_ef%htvp', 'solarabs_vars%sabg_snow_patch', 'solarabs_vars%sabg_soil_patch', 'veg_ef%eflx_sh_snow', 'veg_wf%qflx_ev_snow', 'veg_ef%eflx_sh_soil', 'veg_wf%qflx_ev_soil', 'veg_ef%eflx_sh_h2osfc', 'veg_wf%qflx_ev_h2osfc', 'lun_pp%wtlunit_roof', 'lun_ef%eflx_wasteheat', 'lun_ef%eflx_heat_from_ac', 'lun_ef%eflx_traffic', 'veg_ef%eflx_lwrad_net', 'veg_wf%qflx_tran_veg', 'veg_ef%cgrnd', 'veg_pp%wtcol', 'solarabs_vars%sabg_lyr_patch', 'col_ef%eflx_bot', 'col_es%fact', 'soilstate_vars%sucsat_col', 'soilstate_vars%bsw_col']
# write_types: ['cnstate_vars%som_diffus_coef_col', 'cnstate_vars%som_adv_coef_col', 'col_cs%decomp_cpools_vr', 'col_ns%decomp_npools_vr', 'col_ps%decomp_ppools_vr', 'col_cf%decomp_cpools_transport_tendency', 'col_nf%decomp_npools_transport_tendency', 'col_pf%decomp_ppools_transport_tendency', 'col_ws%frac_iceold', 'lakestate_vars%savedtke1_col', 'col_ef%eflx_snomelt', 'col_ef%imelt', 'col_es%hc_soisno', 'col_es%hc_soi', 'lakestate_vars%lakeresist_col', 'veg_ef%eflx_gnet', 'lakestate_vars%betaprime_col', 'lakestate_vars%lake_icefrac_col', 'col_es%t_lake', 'col_es%t_soisno', 'ch4_vars%grnd_ch4_cond_col', 'col_ef%errsoi', 'veg_ef%eflx_sh_tot', 'veg_ef%eflx_sh_grnd', 'veg_ef%eflx_soil_grnd', 'lakestate_vars%lake_icethick_col', 'col_wf%qflx_snomelt', 'col_wf%qflx_snow_melt', 'col_wf%qflx_snofrz_lyr', 'col_ws%h2osno', 'col_ws%snow_depth', 'col_ws%h2osoi_ice', 'col_ws%h2osoi_liq', 'col_wf%qflx_snofrz', 'col_ef%eflx_urban_ac', 'col_ef%eflx_urban_heat', 'col_ef%xmf_h2osfc', 'col_ef%eflx_fgr12', 'col_ef%eflx_fgr', 'solarabs_vars%sabg_chk_patch', 'veg_ef%eflx_anthro', 'col_wf%qflx_h2osfc_to_ice', 'col_ef%eflx_h2osfc_to_snow', 'col_wf%qflx_snow_melt', 'col_ef%eflx_snomelt_u', 'col_ef%eflx_snomelt_r', 'lun_es%t_building', 'col_es%t_soisno', 'col_es%t_h2osfc', 'col_ef%eflx_building_heat', 'col_es%hc_soisno', 'col_es%hc_soi', 'soilstate_vars%thk_col', 'col_ws%bw', 'col_es%t_grnd', 'veg_ef%eflx_gnet', 'veg_ef%eflx_wasteheat', 'veg_ef%eflx_heat_from_ac', 'veg_ef%eflx_traffic', 'veg_ef%dgnetdt', 'col_es%c_h2osfc', 'col_ws%h2osfc', 'col_ws%snow_depth', 'col_ws%h2osno', 'col_ws%int_snow', 'col_wf%qflx_snomelt', 'col_ef%xmf', 'col_wf%qflx_snofrz_lyr', 'col_wf%qflx_snofrz', 'col_wf%qflx_glcice_melt', 'col_ef%imelt', 'col_ws%h2osoi_ice', 'col_ws%h2osoi_liq', 'col_wf%qflx_glcice', 'col_ef%eflx_snomelt']
# list of global vars: ['soillittverttranspparamsinst', 'canopystate_vars', 'decomp_cascade_con', 'cnstate_vars', 'col_cf', 'col_nf', 'col_pf', 'bounds', 'col_pp', 'veg_pp', 'solarabs_vars', 'lakestate_vars', 'col_es', 'soilstate_vars', 'lun_pp', 'urbanparams_vars', 'col_ws', 'veg_ef', 'top_af', 'veg_wf', 'col_ef', 'lun_ef', 'col_cs', 'col_ns', 'col_ps', 'ch4_vars', 'col_wf', 'lun_es']

# %%
from UnitTestforELM import set_active_variables
instance_to_user_type = {}
elm_inst_vars = {}
for type_name, dtype in type_dict.items():
    if('bounds' in type_name): 
        continue
    if(not dtype.instances):
        print(f"Warning: no instances found for {type_name}")
        cmd = f'grep -rin -E "^[[:space:]]*(type)[[:space:]]*\({type_name}" {ELM_SRC}/main/elm_instMod.F90'
        output = sp.getoutput(cmd)
        print(f"output: {output}")
        if(output):
            output = output.split('\n')
            if(len(output) > 1):
                print(f"Warning: multiple instances found for {type_name}")
                print(output)
                sys.exit(1)
            line = output[0]
            line = line.replace('::','')
            line = line.split(':')
            
            decl = line[1].strip()
            decl = decl.split()
            var = decl[1]
            new_inst = Variable(type_name,var,subgrid='?',ln=0,dim=0,declaration='elm_instMod')
            dtype.instances.append(new_inst)
            elm_inst_vars[var] = dtype
        else:
            print(f"Warning: no instances found for {type_name}")
    for instance in dtype.instances:
        instance_to_user_type[instance.name] = type_name

dtype_info_list = []
    
for s in sub_name_list:
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_r,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_w,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_rw,dtype_info_list)
    
print(dtype_info_list)
# Out:
# [['soillittverttranspparamsinst', 'som_diffus', 'real', '0D'], ['soillittverttranspparamsinst', 'cryoturb_diffusion_k', 'real', '0D'], ['soillittverttranspparamsinst', 'max_altdepth_cryoturbation', 'real', '0D'], ['canopystate_vars', 'altmax_col', 'real', '1D'], ['canopystate_vars', 'altmax_lastyear_col', 'real', '1D'], ['decomp_cascade_con', 'spinup_factor', 'real', '1D'], ['decomp_cascade_con', 'is_cwd', 'logical', '1D'], ['cnstate_vars', 'scalaravg_col', 'real', '2D'], ['col_cf', 'decomp_cpools_sourcesink', 'real', '3D'], ['col_nf', 'decomp_npools_sourcesink', 'real', '3D'], ['col_pf', 'decomp_ppools_sourcesink', 'real', '3D'], ['cnstate_vars', 'som_diffus_coef_col', 'real', '2D'], ['cnstate_vars', 'som_adv_coef_col', 'real', '2D'], ['col_cs', 'decomp_cpools_vr', 'real', '3D'], ['col_ns', 'decomp_npools_vr', 'real', '3D'], ['col_ps', 'decomp_ppools_vr', 'real', '3D'], ['col_cf', 'decomp_cpools_transport_tendency', 'real', '3D'], ['col_nf', 'decomp_npools_transport_tendency', 'real', '3D'], ['col_pf', 'decomp_ppools_transport_tendency', 'real', '3D'], ['col_pp', 'snl', 'integer', '1D'], ['veg_pp', 'column', 'integer', '1D'], ['solarabs_vars', 'fsds_nir_d_patch', 'real', '1D'], ['solarabs_vars', 'fsds_nir_i_patch', 'real', '1D'], ['solarabs_vars', 'fsr_nir_d_patch', 'real', '1D'], ['solarabs_vars', 'fsr_nir_i_patch', 'real', '1D'], ['solarabs_vars', 'sabg_patch', 'real', '1D'], ['col_pp', 'z_lake', 'real', '2D'], ['lakestate_vars', 'ws_col', 'real', '1D'], ['lakestate_vars', 'ks_col', 'real', '1D'], ['col_es', 't_grnd', 'real', '1D'], ['col_pp', 'lakedepth', 'real', '1D'], ['lakestate_vars', 'etal_col', 'real', '1D'], ['col_pp', 'dz_lake', 'real', '2D'], ['solarabs_vars', 'sabg_lyr_patch', 'real', '2D'], ['col_pp', 'z', 'real', '2D'], ['col_pp', 'dz', 'real', '2D'], ['lakestate_vars', 'lake_raw_col', 'real', '1D'], ['soilstate_vars', 'tksatu_col', 'real', '2D'], ['soilstate_vars', 'tkmg_col', 'real', '2D'], ['soilstate_vars', 'watsat_col', 'real', '2D'], ['soilstate_vars', 'tkdry_col', 'real', '2D'], ['col_pp', 'zi', 'real', '2D'], ['soilstate_vars', 'csol_col', 'real', '2D'], ['col_ws', 'frac_iceold', 'real', '2D'], ['lakestate_vars', 'savedtke1_col', 'real', '1D'], ['col_ef', 'eflx_snomelt', 'real', '1D'], ['col_ef', 'imelt', 'integer', '2D'], ['col_es', 'hc_soisno', 'real', '1D'], ['col_es', 'hc_soi', 'real', '1D'], ['lakestate_vars', 'lakeresist_col', 'real', '1D'], ['veg_ef', 'eflx_gnet', 'real', '1D'], ['lakestate_vars', 'betaprime_col', 'real', '1D'], ['lakestate_vars', 'lake_icefrac_col', 'real', '2D'], ['col_es', 't_lake', 'real', '2D'], ['col_es', 't_soisno', 'real', '2D'], ['ch4_vars', 'grnd_ch4_cond_col', 'real', '1D'], ['col_ef', 'errsoi', 'real', '1D'], ['veg_ef', 'eflx_sh_tot', 'real', '1D'], ['veg_ef', 'eflx_sh_grnd', 'real', '1D'], ['veg_ef', 'eflx_soil_grnd', 'real', '1D'], ['lakestate_vars', 'lake_icethick_col', 'real', '1D'], ['col_wf', 'qflx_snomelt', 'real', '1D'], ['col_wf', 'qflx_snow_melt', 'real', '1D'], ['col_wf', 'qflx_snofrz_lyr', 'real', '2D'], ['col_ws', 'h2osno', 'real', '1D'], ['col_ws', 'snow_depth', 'real', '1D'], ['col_ws', 'h2osoi_ice', 'real', '2D'], ['col_ws', 'h2osoi_liq', 'real', '2D'], ['col_wf', 'qflx_snofrz', 'real', '1D'], ['lun_pp', 'urbpoi', 'logical', '1D'], ['urbanparams_vars', 't_building_max', 'real', '1D'], ['urbanparams_vars', 't_building_min', 'real', '1D'], ['col_pp', 'itype', 'integer', '1D'], ['col_pp', 'landunit', 'integer', '1D'], ['col_ws', 'frac_h2osfc', 'real', '1D'], ['col_es', 't_ssbef', 'real', '2D'], ['col_ws', 'frac_sno_eff', 'real', '1D'], ['lun_pp', 'itype', 'integer', '1D'], ['col_pp', 'nlevbed', 'integer', '1D'], ['urbanparams_vars', 'tk_wall', 'real', '2D'], ['urbanparams_vars', 'tk_roof', 'real', '2D'], ['urbanparams_vars', 'nlev_improad', 'integer', '1D'], ['urbanparams_vars', 'tk_improad', 'real', '2D'], ['urbanparams_vars', 'cv_wall', 'real', '2D'], ['urbanparams_vars', 'cv_roof', 'real', '2D'], ['urbanparams_vars', 'cv_improad', 'real', '2D'], ['col_ ...

# %%
for sub in subroutines.values():
    tree = sub.calltree[2:]
    sub.analyze_calltree(tree,case_dir)
# Out:
# soillittverttransp
# |---->tridiagonal_sr
# laketemperature
# |---->soilthermprop_lake
# |---->tridiagonal_sr
# |---->phasechange_lake
# soiltemperature
# |---->soilthermprop
# |---->computegroundheatfluxandderiv
# |---->computeheatdifffluxandfactor
# |---->solvetemperature
# |---->|---->setrhsvec
# |---->|---->|---->setrhsvec_snow
# |---->|---->|---->|---->setrhsvec_snowurban
# |---->|---->|---->|---->|---->setrhsvec_snowurbannonroad
# |---->|---->|---->|---->|---->setrhsvec_snowurbanroad
# |---->|---->|---->|---->setrhsvec_snownonurban
# |---->|---->|---->setrhsvec_standingsurfacewater
# |---->|---->|---->setrhsvec_soil
# |---->|---->|---->|---->setrhsvec_soilurban
# |---->|---->|---->|---->|---->setrhsvec_soilurbannonroad
# |---->|---->|---->|---->|---->setrhsvec_soilurbanroad
# |---->|---->|---->|---->setrhsvec_soilnonurban
# |---->|---->|---->|---->setrhsvec_soil_standingsurfacewater
# |---->|---->setmatrix
# |---->|---->|---->setmatrix_snow
# |---->|---->|---->|---->setmatrix_snowurban
# |---->|---->|---->|---->|---->setmatrix_snowurbannonroad
# |---->|---->|---->|---->|---->setmatrix_snowurbanroad
# |---->|---->|---->|---->setmatrix_snownonurban
# |---->|---->|---->setmatrix_snow_soil
# |---->|---->|---->|---->setmatrix_snow_soilurban
# |---->|---->|---->|---->|---->setmatrix_snow_soilurbannonroad
# |---->|---->|---->|---->|---->setmatrix_snow_soilurbanroad
# |---->|---->|---->|---->setmatrix_snow_soilnonurban
# |---->|---->|---->setmatrix_soil
# |---->|---->|---->|---->setmatrix_soilurban
# |---->|---->|---->|---->|---->setmatrix_soilurbannonroad
# |---->|---->|---->|---->|---->setmatrix_soilurbanroad
# |---->|---->|---->|---->setmatrix_soilnonurban
# |---->|---->|---->setmatrix_soil_snow
# |---->|---->|---->|---->setmatrix_soil_snowurban
# |---->|---->|---->|---->|---->setmatrix_soil_snowurbannonroad
# |---->|---->|---->|---->|---->setmatrix_soil_snowurbanroad
# |---->|---->|---->|---->setmatrix_soil_snownonurban
# |---->|---->|---->setmatrix_standingsurfacewater
# |---->|---->|---->setmatrix_standingsurfacewater_soil
# |---->|---->|---->setmatrix_soil_standingsurfacewater
# |---->|---->|---->assemblematrixfromsubmatrices
# |---->|---->banddiagonal
# |---->|---->|---->dgbsv
# |---->phasechangeh2osfc
# |---->phasechange_beta
