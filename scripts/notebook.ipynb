# %% [markdown]
# # Demo for SPEL

# %%
# %tb
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Built-in modules
import re        # Regular expressions
import importlib # MUST BE USED TO RELOAD MODULES
import sys 

# Importing modules for SPEL functions 
import utilityFunctions as uf
import edit_files as ef 
import fortran_modules as fm 
from analyze_subroutines import Subroutine

# mod_config : system configuration and static variables. 
# Where E3SM is stored, where unit tests are stored, etc.
from mod_config import default_mods, unittests_dir, scripts_dir, spel_mods_dir
from mod_config import ELM_SRC, spel_output_dir, _bc

# %% [markdown]
# SPEL needs a "casename" (what your unit-test is called) and a list of subroutines to create a unit-test for "sub_name_list" (examples are "LakeTemperature", "SoilTemperature", etc...)

# %%
# Define Unit Test parameters 
import os 
casename = "notebook_test"  # Name of the test case
case_dir = unittests_dir + casename # Directory to store the test case

# create directory for unit-test if it does not exist
if(not os.path.isdir(f"{case_dir}") ):
    print(f"Making case directory {case_dir}")
    if(not os.path.isdir(f"{unittests_dir}")):
        os.system(f"mkdir {unittests_dir}")
    os.system(f"mkdir {case_dir}")
    preprocess = True

# List of subroutines to be analyzed
# sub_name_list = ["SoilLittVertTransp","LakeTemperature","SoilTemperature"] 
sub_name_list = ["SoilTemperature"] 
sub_name_list = [sub.lower() for sub in sub_name_list]

# variables needed for Unit Test
main_sub_dict = {}  # Dictionary to store all Subroutines in files needed for Unit Test
mod_dict = {} 
subroutines = {k.lower():[] for k in sub_name_list} # Dictionary for User Specified Subroutines

# %% [markdown]
# 1st step for SPEL is determine which modules are needed for LakeTemperature and edit out the I/O, MPI, and other unneccessary modules. This must be somewhat tailored to ELM.
#
# Currently if I module is not present in the "components/elm/src/" (ELM_SRC) nor in the "share/utils" directories (SHR_SRC), then the module and any dependency on it is automatically removed.

# %%
 # List to hold all the modules needed for the unit test
needed_mods = [] 
for s in sub_name_list:
    # Get general info of the subroutine
    subroutines[s] = Subroutine(s,calltree=['elm_drv'])

    # Process by removing certain modules and syntax
    # so that a standalone unit test can be compiled.
    fn = subroutines[s].filepath
    mod_dict, file_list, main_sub_dict = ef.process_for_unit_test(
                fname=fn,
                case_dir=case_dir,
                mod_dict=mod_dict,
                mods=needed_mods,
                required_mods=default_mods,
                main_sub_dict=main_sub_dict,
                overwrite=True,
                verbose=False,
            )

    subroutines[s] = main_sub_dict[s]

# %%
# Create dictionary containing all identified user defined types
# 'type-name' : 'DerivedType Object'
type_dict = {}
for modname, mod in mod_dict.items():
    for utype, dtype in mod.defined_types.items():
        type_dict[utype] = dtype

# %% [markdown]
# SPEL can print out a module tree showing how the modules are linked for the unit-test subroutines
# - The full tree can be pretty difficult to parse, having a cutoff depth is recommended.
# - Every module uses 'shr_kind_mod' so that could be suppressed as well.

# %%
modtree = fm.print_spel_module_dependencies(mod_dict=mod_dict,subs=subroutines)

# Print the module tree
arrow = "-->"
cutoff_depth = 10 # Only print modules up to this depth
suppress_mod_list = ['shr_kind_mod']
for m in modtree:
    depth = m['depth']
    modname = m['module']
    if(modname in suppress_mod_list):
        continue
    if(depth == 1):
        print(_bc.HEADER + arrow*depth + modname + _bc.ENDC)
    elif(depth <= cutoff_depth):
        print( arrow*depth + modname)

# %%
test_mod = mod_dict['soiltemperaturemod']
test_mod.print_module_info()

# %%
for s in sub_name_list:
    # Parsing means getting info on the variables read and written
    # to by the subroutine and any of its callees
    subroutines[s].parse_subroutine(dtype_dict=type_dict,
                                    main_sub_dict=main_sub_dict,verbose=True)

# %%
read_types  = [] 
write_types = []
func_name = "Notebook"
for s in sub_name_list:
    subroutines[s].child_subroutines_analysis(dtype_dict=type_dict,
                                        main_sub_dict=main_sub_dict,verbose=True)

    print(_bc.OKGREEN + f"Derived Type Analysis for {subroutines[s].name}")
    print(f"{func_name}::Read-Only")
    for key in subroutines[s].elmtype_r.keys():
        print(key, subroutines[s].elmtype_r[key])
    print(f"{func_name}::Write-Only")
    for key in subroutines[s].elmtype_w.keys():
        print(key, subroutines[s].elmtype_w[key])
    print(f"{func_name}::Read-Write")
    for key in subroutines[s].elmtype_rw.keys():
        print(key, subroutines[s].elmtype_rw[key])
    print(_bc.ENDC)

    for key in list(subroutines[s].elmtype_r.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_r[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        read_types.append(key)

    for key in list(subroutines[s].elmtype_w.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_w[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        write_types.append(key)

    for key in list(subroutines[s].elmtype_rw.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_rw[key]
            continue
        write_types.append(key)

# %%
# Make sure physical properties types are read/written:
list_pp = ['veg_pp','lun_pp','col_pp','grc_pp','top_pp']

print("read_types:",read_types)
print("write_types:",write_types)

aggregated_elmtypes_list = []
for x in read_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)    
for x in write_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)

# for l in list_pp:
#     aggregated_elmtypes_list.append(l)
print("list of global vars:",aggregated_elmtypes_list)

# %%
from UnitTestforELM import set_active_variables
instance_to_user_type = {}
elm_inst_vars = {}
for type_name, dtype in type_dict.items():
    if('bounds' in type_name): 
        continue
    if(not dtype.instances):
        print(f"Warning: no instances found for {type_name}")
        cmd = f'grep -rin -E "^[[:space:]]*(type)[[:space:]]*\({type_name}" {ELM_SRC}/main/elm_instMod.F90'
        output = sp.getoutput(cmd)
        print(f"output: {output}")
        if(output):
            output = output.split('\n')
            if(len(output) > 1):
                print(f"Warning: multiple instances found for {type_name}")
                print(output)
                sys.exit(1)
            line = output[0]
            line = line.replace('::','')
            line = line.split(':')
            
            decl = line[1].strip()
            decl = decl.split()
            var = decl[1]
            new_inst = Variable(type_name,var,subgrid='?',ln=0,dim=0,declaration='elm_instMod')
            dtype.instances.append(new_inst)
            elm_inst_vars[var] = dtype
        else:
            print(f"Warning: no instances found for {type_name}")
    for instance in dtype.instances:
        instance_to_user_type[instance.name] = type_name

dtype_info_list = []
    
for s in sub_name_list:
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_r,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_w,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_rw,dtype_info_list)
    
print(dtype_info_list)

# %%
for sub in subroutines.values():
    tree = sub.calltree[2:]
    sub.analyze_calltree(tree,case_dir)

# %%
import export_objects as eo
import importlib
importlib.reload(eo)
mod_dict, sub_dict, type_dict = {}, {}, {}

# %%
mod_dict, sub_dict, type_dict = eo.unpickle_unit_test(mod_dict, sub_dict, type_dict)

# %%
with open("mod.txt", 'w') as file:
    for i in mod_dict.keys():
        mod_dict[i].print_module_info(ofile=file)

# %%
import csv
with open("mod.csv",'w') as file:
    writer = csv.writer(file, delimiter=",")
    writer.writerow(["module_name", "dependency", "object_used"])
    
    with open("mod.txt", "r") as r:
        for j in mod_dict.keys():
            dep = ""
            for i in r: 
                if i[0] != ' ': dep = i
                if i[:2] == "  ": writer.writerow([j.strip(), dep.strip(), i.strip()])
                print(i)
# Out:
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# ch4mod
#
#   ch4_type
#
#
#
# energyfluxtype
#
#   energyflux_type
#
#
#
# lakestatetype
#
#   lakestate_type
#
#
#
# soilstatetype
#
#   soilstate_type
#
#
#
# solarabsorbedtype
#
#   solarabs_type
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_es
#
#   col_ef
#
#   col_ws
#
#   col_wf
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# vegetationdatatype
#
#   veg_ef
#
#
#
# timeinfomod
#
#   all
#
# lakecon
#
#   betavis
#
#   za_lake
#
#   n2min
#
#   tdmax
#
#   pudz
#
#   depthcrit
#
#   mixfact
#
#   lakepuddling
#
#   lake_no_ed
#
#
#
# qsatmod
#
#   qsat
#
#
#
# tridiagonalmod
#
#   tridiagonal
#
#
#
# elm_varpar
#
#   nlevlak
#
#   nlevgrnd
#
#   nlevsno
#
#   nlevsoi
#
#
#
# elm_varcon
#
#   hfus
#
#   cpliq
#
#   cpice
#
#   tkwat
#
#   tkice
#
#   denice
#
#   vkc
#
#   grav
#
#   denh2o
#
#   tfrz
#
#   cnfac
#
#   tkair
#
#   thk_bedrock
#
#
#
# elm_varctl
#
#   iulog
#
#   use_lch4
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# elm_varcon
#
#   grlnd
#
#   nameg
#
#   namet
#
#   namel
#
#   namec
#
#   namep
#
#   namecohort
#
#
#
# domainmod
#
#   ldomain
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nlevsoi
#
#   ngases
#
#   nlevsno
#
#   nlevdecomp
#
#   nlevgrnd
#
#   nlevdecomp_full
#
#
#
# elm_varcon
#
#   denh2o
#
#   denice
#
#   tfrz
#
#   grav
#
#   spval
#
#   rgas
#
#   grlnd
#
#   catomw
#
#   s_con
#
#   d_con_w
#
#   d_con_g
#
#   c_h_inv
#
#   kh_theta
#
#   kh_tbase
#
#   secspday
#
#   rpi
#
#
#
# landunit_varcon
#
#   istdlak
#
#   istsoil
#
#   istcrop
#
#
#
# elm_varctl
#
#   iulog
#
#   use_cn
#
#   use_lch4
#
#   use_fates
#
#   hist_wrtch4diag
#
#   fsurdat
#
#   anoxia
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# sharedparamsmod
#
#   paramsshareinst
#
#   nlev_soildecomp_standard
#
#
#
# atm2lndtype
#
#   atm2lnd_type
#
#
#
# canopystatetype
#
#   canopystate_type
#
#
#
# energyfluxtype
#
#   energyflux_type
#
#
#
# lakestatetype
#
#   lakestate_type
#
#
#
# lnd2atmtype
#
#   lnd2atm_type
#
#
#
# soilhydrologytype
#
#   soilhydrology_type
#
#
#
# soilstatetype
#
#   soilstate_type
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# topounitdatatype
#
#   top_as
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_es
#
#   col_ws
#
#   col_wf
#
#   col_cf
#
#   col_nf
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# vegetationdatatype
#
#   veg_wf
#
#   veg_cs
#
#   veg_cf
#
#
#
# timeinfomod
#
#   all
#
# topounit_varcon
#
#   max_topounits
#
#
#
# ch4varcon
#
#   allowlakeprod
#
#   usephfact
#
#   fin_use_fsat
#
#   use_aereoxid_prog
#
#   replenishlakec
#
#   ch4offline
#
#   transpirationloss
#
#   usefrootc
#
#   ch4frzout
#
#
#
# pftvarcon
#
#   noveg
#
#   nc3_arctic_grass
#
#   crop
#
#   nc3_nonarctic_grass
#
#   nc4_grass
#
#
#
# lakecon
#
#   all
#
# tridiagonalmod
#
#   tridiagonal
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   numrad
#
#   ndst
#
#   nlevgrnd
#
#
#
# elm_varcon
#
#   rair
#
#   grav
#
#   cpair
#
#   hfus
#
#   tfrz
#
#   spval
#
#
#
# elm_varctl
#
#   iulog
#
#   use_c13
#
#   use_cn
#
#   use_lch4
#
#   use_fates
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# elm_varpar
#
#   nlevcan
#
#   nvegwcs
#
#   nlevgrnd
#
#
#
# elm_varctl
#
#   iulog
#
#   use_cn
#
#   use_fates
#
#   use_hydrstress
#
#   use_fates_sp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   numrad
#
#   ndst
#
#   nlevsno
#
#   nlevgrnd
#
#
#
# elm_varcon
#
#   rair
#
#   grav
#
#   cpair
#
#   hfus
#
#   tfrz
#
#   spval
#
#
#
# elm_varctl
#
#   iulog
#
#   use_c13
#
#   use_cn
#
#   use_lch4
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   nlevgrnd
#
#   nlayer
#
#   nlayert
#
#   nlevsoi
#
#   more_vertlayers
#
#   nlevsoifl
#
#   toplev_equalspace
#
#   nlevsno
#
#   crop_prog
#
#   nlevlak
#
#   nlevurb
#
#
#
# elm_varcon
#
#   zsoi
#
#   dzsoi
#
#   zisoi
#
#   spval
#
#   denice
#
#   denh2o
#
#   sb
#
#   bdsno
#
#   h2osno_max
#
#   zlnd
#
#   tfrz
#
#   pc
#
#   nlvic
#
#   dzvic
#
#   mu
#
#   grlnd
#
#
#
# elm_varctl
#
#   iulog
#
#   create_glacier_mec_landunit
#
#   use_cn
#
#   use_lch4
#
#   fsurdat
#
#   use_vichydro
#
#   use_var_soil_thick
#
#
#
# sharedparamsmod
#
#   paramsshareinst
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# shr_const_mod
#
#   shr_const_pi
#
#   shr_const_tkfrz
#
#
#
# shr_spfn_mod
#
#   shr_spfn_erf
#
#
#
# landunit_varcon
#
#   istice
#
#   istwet
#
#   istsoil
#
#   istdlak
#
#   istcrop
#
#   istice_mec
#
#
#
# column_varcon
#
#   icol_shadewall
#
#   icol_road_perv
#
#   icol_road_imperv
#
#   icol_roof
#
#   icol_sunwall
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_kind_mod
#
#   r4 => shr_kind_r4
#
#   r8 => shr_kind_r8
#
#
#
# shr_const_mod
#
#   pi => shr_const_pi
#
#
#
# landunit_varcon
#
#   isturb_min
#
#   istsoil
#
#   istcrop
#
#   istice_mec
#
#
#
# elm_varpar
#
#   maxpatch_glcmec
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# landunit_varcon
#
#   max_lunit
#
#
#
# elm_varcon
#
#   ispval
#
#   spval
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# elm_varctl
#
#   iulog
#
#   use_cn
#
#   use_fates
#
#   use_lch4
#
#
#
# elm_varpar
#
#   numrad
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# topounittype
#
#   top_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# landunit_varcon
#
#   max_lunit
#
#
#
# elm_varcon
#
#   ispval
#
#   spval
#
#
#
# elm_varpar
#
#   numrad
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   ispval
#
#   spval
#
#
#
# elm_varctl
#
#   fsurdat
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   grlnd
#
#
#
# domainmod
#
#   domain_type
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#   nlfilename_in
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   mxpft
#
#   numrad
#
#   ivis
#
#   inir
#
#   cft_lb
#
#   cft_ub
#
#   mxpft_nc
#
#   nlevdecomp_full
#
#   nsoilorder
#
#
#
# elm_varctl
#
#   iulog
#
#   use_vertsoilc
#
#   nu_com
#
#   paramfile
#
#   use_fates
#
#   use_crop
#
#   use_dynroot
#
#
#
# elm_varcon
#
#   tfrz
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   spval
#
#   denice
#
#   denh2o
#
#   sb
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# annualfluxdribbler
#
#   annual_flux_dribbler_type
#
#   annual_flux_dribbler_gridcell
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   crop_prog
#
#   nlevsoi
#
#   nlevurb
#
#
#
# elm_varctl
#
#   use_cn
#
#   iulog
#
#   use_vancouver
#
#   use_mexicocity
#
#
#
# shr_const_mod
#
#   shr_const_tkfrz
#
#
#
# landunit_varcon
#
#   istice
#
#   istwet
#
#   istsoil
#
#   istdlak
#
#   istice_mec
#
#
#
# column_varcon
#
#   icol_road_imperv
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#   icol_road_perv
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#   get_beg
#
#   get_end
#
#   bounds_subgrid_gridcell
#
#   bounds_subgrid_patch
#
#
#
# elm_varcon
#
#   secspday
#
#   nameg
#
#   namep
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   spval
#
#   grlnd
#
#   tkwat
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# elm_varpar
#
#   nlevlak
#
#   nlevsno
#
#
#
# elm_varctl
#
#   fsurdat
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   more_vertlayers
#
#   numpft
#
#   numrad
#
#   nlevsoi
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevsoifl
#
#   nlayer
#
#   nlayert
#
#   nlevurb
#
#   nlevsno
#
#
#
# landunit_varcon
#
#   istice
#
#   istdlak
#
#   istwet
#
#   istsoil
#
#   istcrop
#
#   istice_mec
#
#   max_lunit
#
#
#
# column_varcon
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#   icol_road_perv
#
#   icol_road_imperv
#
#
#
# elm_varcon
#
#   zsoi
#
#   dzsoi
#
#   zisoi
#
#   spval
#
#   namet
#
#   grlnd
#
#   secspday
#
#   pc
#
#   mu
#
#   denh2o
#
#   denice
#
#
#
# elm_varctl
#
#   use_cn
#
#   use_lch4
#
#   use_dynroot
#
#   use_fates
#
#   use_erosion
#
#   use_var_soil_thick
#
#   iulog
#
#   fsurdat
#
#   hist_wrtch4diag
#
#   use_hydrstress
#
#
#
# ch4varcon
#
#   allowlakeprod
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# pftvarcon
#
#   noveg
#
#   roota_par
#
#   rootb_par
#
#
#
# sharedparamsmod
#
#   paramsshareinst
#
#
#
# funcpedotransfermod
#
#   pedotransf
#
#   get_ipedof
#
#
#
# rootbiophysmod
#
#   init_vegrootfr
#
#
#
# domainlateralmod
#
#   exchangecolumnlevelghostdata
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# pftvarcon
#
#   noveg
#
#   roota_par
#
#   rootb_par
#
#
#
# elm_varctl
#
#   use_var_soil_thick
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# decompmod
#
#   ldecomp
#
#   get_proc_bounds
#
#   bounds_type
#
#   bounds_level_proc
#
#
#
# landunit_varcon
#
#   max_lunit
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varcon
#
#   spval
#
#
#
# elm_varpar
#
#   nlevcan
#
#   numrad
#
#   nlevsno
#
#
#
# elm_varctl
#
#   use_snicar_frc
#
#   iulog
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevslp
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_const_mod
#
#   shr_const_tkfrz
#
#   shr_const_pdb
#
#
#
# elm_varpar
#
#   nlevsoi
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevurb
#
#   ndecomp_cascade_transitions
#
#   ndecomp_pools
#
#   nlevcan
#
#   nlevdecomp_full
#
#   crop_prog
#
#   nlevdecomp
#
#   i_met_lit
#
#   i_cel_lit
#
#   i_lig_lit
#
#   i_cwd
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#   zlnd
#
#   snw_rds_min
#
#   denice
#
#   denh2o
#
#   tfrz
#
#   pondmx
#
#   watmin
#
#   bdsno
#
#   zsoi
#
#   zisoi
#
#   dzsoi_decomp
#
#   c13ratio
#
#   c14ratio
#
#   secspday
#
#
#
# elm_varctl
#
#   use_fates
#
#   use_fates_planthydro
#
#   create_glacier_mec_landunit
#
#   use_hydrstress
#
#   bound_h2osoi
#
#   use_cn
#
#   iulog
#
#   use_vertsoilc
#
#   spinup_state
#
#   use_erosion
#
#   use_elm_interface
#
#   use_pflotran
#
#   pf_cmode
#
#   hist_wrtch4diag
#
#   use_century_decomp
#
#   get_carbontag
#
#   override_bgc_restart_mismatch_dump
#
#   pf_hmode
#
#   nu_com
#
#   use_vancouver
#
#   use_mexicocity
#
#   use_lake_wat_storage
#
#
#
# ch4varcon
#
#   allowlakeprod
#
#
#
# pftvarcon
#
#   vmax_minsurf_p_vr
#
#   km_minsurf_p_vr
#
#   pinit_beta1
#
#   pinit_beta2
#
#
#
# soilorder_varcon
#
#   smax
#
#   ks_sorption
#
#
#
# landunit_varcon
#
#   istice
#
#   istwet
#
#   istsoil
#
#   istdlak
#
#   istcrop
#
#   istice_mec
#
#
#
# column_varcon
#
#   icol_road_perv
#
#   icol_road_imperv
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# cnstatetype
#
#   cnstate_type
#
#
#
# cndecompcascadecontype
#
#   decomp_cascade_con
#
#
#
# columntype
#
#   col_pp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# urbanparamstype
#
#   urbanparams_vars
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nsoilorder
#
#
#
# elm_varctl
#
#   iulog
#
#   use_vertsoilc
#
#   fsoilordercon
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevsoifl
#
#   nlevsoi
#
#   crop_prog
#
#   ndecomp_cascade_transitions
#
#   nlevdecomp
#
#   nlevdecomp_full
#
#   more_vertlayers
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#   c14ratio
#
#   grlnd
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#
#
# elm_varctl
#
#   use_vertsoilc
#
#   use_c14
#
#   use_cn
#
#   iulog
#
#   fsurdat
#
#   forest_fert_exp
#
#   nu_com
#
#   use_fates
#
#   use_crop
#
#   nsrest
#
#   nsrstartup
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   ndecomp_cascade_transitions
#
#   ndecomp_pools
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varctl
#
#   iulog
#
#   fsurdat
#
#   use_vancouver
#
#   use_mexicocity
#
#
#
# elm_varcon
#
#   namel
#
#   grlnd
#
#   spval
#
#   vkc
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# topounit_varcon
#
#   max_topounits
#
#   has_topounit
#
#
#
# elm_varpar
#
#   nlevcan
#
#   numrad
#
#   nlevgrnd
#
#   nlevurb
#
#   nlevsoi
#
#
#
# column_varcon
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#   icol_road_perv
#
#   icol_road_imperv
#
#
#
# landunit_varcon
#
#   isturb_min
#
#   numurbl
#
#
#
# domainmod
#
#   ldomain
#
#
#
# elm_varsur
#
#   urban_valid
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varcon
#
#   ispval
#
#   spval
#
#
#
# elm_varctl
#
#   use_fates
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_const_mod
#
#   shr_const_pdb
#
#   shr_const_cday
#
#   shr_const_tkfrz
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevurb
#
#   nlevcan
#
#   crop_prog
#
#   nlevdecomp
#
#   nlevdecomp_full
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#   sb
#
#   c13ratio
#
#   c14ratio
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#
#
# pftvarcon
#
#   npcropmin
#
#   noveg
#
#   nstor
#
#
#
# elm_varctl
#
#   iulog
#
#   use_cn
#
#   spinup_state
#
#   spinup_mortality_factor
#
#   use_fates
#
#   nu_com
#
#   use_crop
#
#   use_c13
#
#   use_lch4
#
#   use_betr
#
#   use_vancouver
#
#   use_mexicocity
#
#   nsrest
#
#   nsrstartup
#
#
#
# decompmod
#
#   bounds_type
#
#   get_proc_global
#
#
#
# subgridavemod
#
#   p2c
#
#   p2c_1d_filter
#
#
#
# cnstatetype
#
#   cnstate_type
#
#
#
# speciesmod
#
#   species_from_string
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# vegetationpropertiestype
#
#   veg_vp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# columndatatype
#
#   col_es
#
#   column_carbon_state
#
#   column_carbon_flux
#
#   column_nitrogen_state
#
#   column_nitrogen_flux
#
#   column_phosphorus_state
#
#   column_phosphorus_flux
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# column_varcon
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#   icol_road_perv
#
#   icol_road_imperv
#
#
#
# elm_varcon
#
#   grlnd
#
#   nameg
#
#   namet
#
#   namel
#
#   namec
#
#   namep
#
#   spval
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# topounittype
#
#   top_pp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#   column_physical_properties
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# landunit_varcon
#
#   max_lunit
#
#   istsoil
#
#   istcrop
#
#   istice
#
#   istice_mec
#
#   istdlak
#
#   isturb_min
#
#   isturb_max
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nlevdecomp
#
#   nsoilorder
#
#   numrad
#
#   numpft
#
#
#
# elm_varctl
#
#   nu_com
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# pftvarcon
#
#   ntree
#
#   smpso
#
#   smpsc
#
#   fnitr
#
#   z0mr
#
#   displar
#
#   dleaf
#
#   rhol
#
#   rhos
#
#   taul
#
#   taus
#
#   xl
#
#   c3psn
#
#   slatop
#
#   dsladlai
#
#   leafcn
#
#   flnr
#
#   woody
#
#   lflitcn
#
#   frootcn
#
#   livewdcn
#
#   deadwdcn
#
#   froot_leaf
#
#   stem_leaf
#
#   croot_stem
#
#   flivewd
#
#   fcur
#
#   lf_flab
#
#   lf_fcel
#
#   lf_flig
#
#   fr_flab
#
#   fr_fcel
#
#   fr_flig
#
#   leaf_long
#
#   froot_long
#
#   evergreen
#
#   stress_decid
#
#   season_decid
#
#   fertnitro
#
#   graincn
#
#   fleafcn
#
#   ffrootcn
#
#   fstemcn
#
#   dwood
#
#   presharv
#
#   convfact
#
#   fyield
#
#   leafcp
#
#   lflitcp
#
#   frootcp
#
#   livewdcp
#
#   deadwdcp
#
#   graincp
#
#   vmax_plant_nh4
#
#   vmax_plant_no3
#
#   vmax_plant_p
#
#   vmax_minsurf_p_vr
#
#   km_plant_nh4
#
#   km_plant_no3
#
#   km_plant_p
#
#   km_minsurf_p_vr
#
#   km_decomp_nh4
#
#   km_decomp_no3
#
#   km_decomp_p
#
#   km_nit
#
#   km_den
#
#   decompmicc_patch_vr
#
#   vmax_nfix
#
#   km_nfix
#
#   alpha_nfix
#
#   alpha_ptase
#
#   ccost_nfix
#
#   ccost_ptase
#
#   vmax_ptase
#
#   km_ptase
#
#   lamda_ptase
#
#   i_vc
#
#   s_vc
#
#   nsc_rtime
#
#   pinit_beta1
#
#   pinit_beta2
#
#   leafcn_obs
#
#   frootcn_obs
#
#   livewdcn_obs
#
#   deadwdcn_obs
#
#   leafcp_obs
#
#   frootcp_obs
#
#   livewdcp_obs
#
#   deadwdcp_obs
#
#   fnr
#
#   act25
#
#   kcha
#
#   koha
#
#   cpha
#
#   vcmaxha
#
#   jmaxha
#
#   tpuha
#
#   lmrha
#
#   vcmaxhd
#
#   jmaxhd
#
#   tpuhd
#
#   lmrse
#
#   qe
#
#   theta_cj
#
#   bbbopt
#
#   mbbopt
#
#   nstor
#
#   br_xr
#
#   tc_stress
#
#   lmrhd
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_const_mod
#
#   shr_const_tkfrz
#
#
#
# elm_varcon
#
#   rwat
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   use_extralakelayers
#
#   use_vertsoilc
#
#   use_crop
#
#   use_betr
#
#   use_century_decomp
#
#   use_c13
#
#   use_c14
#
#   use_fates
#
#   iulog
#
#   create_crop_landunit
#
#   irrigate
#
#   use_vichydro
#
#   use_extrasnowlayers
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# shr_const_mod
#
#   shr_const_g
#
#   shr_const_stebol
#
#   shr_const_karman
#
#   shr_const_rwv
#
#   shr_const_rdair
#
#   shr_const_cpfw
#
#   shr_const_cpice
#
#   shr_const_cpdair
#
#   shr_const_latvap
#
#   shr_const_latsub
#
#   shr_const_latice
#
#   shr_const_rhofw
#
#   shr_const_rhoice
#
#   shr_const_tkfrz
#
#   shr_const_rearth
#
#   shr_const_pdb
#
#   shr_const_pi
#
#   shr_const_cday
#
#   shr_const_rgas
#
#
#
# elm_varpar
#
#   numrad
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevdecomp_full
#
#   ngases
#
#   nlayer
#
#   nlevsoifl
#
#
#
# elm_varctl
#
#   use_extrasnowlayers
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#   shr_kind_cl
#
#   shr_kind_cs
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#   create_crop_landunit
#
#
#
# elm_varpar
#
#   natpft_size
#
#   cft_size
#
#   maxpatch_urb
#
#   maxpatch_glcmec
#
#
#
# elm_varsur
#
#   wt_lunit
#
#   urban_valid
#
#   wt_glc_mec
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#   istice
#
#   istice_mec
#
#   istdlak
#
#   istwet
#
#   isturb_tbd
#
#   isturb_hd
#
#   isturb_md
#
#
#
# topounit_varcon
#
#   max_topounits
#
#   has_topounit
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# decompmod
#
#   bounds_type
#
#   get_proc_clumps
#
#   get_clump_bounds
#
#   bounds_level_clump
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# topounittype
#
#   top_pp
#
#
#
# pftvarcon
#
#   npcropmin
#
#   nppercropmin
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#   istice_mec
#
#
#
# column_varcon
#
#   icol_road_perv
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varctl
#
#   iulog
#
#   use_petsc_thermal_model
#
#
#
# elm_varcon
#
#   spval
#
#   cnfac
#
#   cpice
#
#   cpliq
#
#   denh2o
#
#   denice
#
#   tfrz
#
#   tkwat
#
#   tkice
#
#   tkair
#
#   thk_bedrock
#
#   hfus
#
#   grav
#
#   sb
#
#   hvap
#
#   capr
#
#
#
# urbanparamstype
#
#   urbanparams_type
#
#
#
# atm2lndtype
#
#   atm2lnd_type
#
#
#
# canopystatetype
#
#   canopystate_type
#
#
#
# solarabsorbedtype
#
#   solarabs_type
#
#
#
# soilstatetype
#
#   soilstate_type
#
#
#
# energyfluxtype
#
#   energyflux_type
#
#
#
# topounitdatatype
#
#   top_af
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# landunitdatatype
#
#   lun_es
#
#   lun_ef
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_es
#
#   col_ef
#
#   col_ws
#
#   col_wf
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# vegetationdatatype
#
#   veg_ef
#
#   veg_wf
#
#
#
# timeinfomod
#
#   all
#
# perfmod_gpu
#
#   all
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevurb
#
#   nlevsoi
#
#   max_patch_per_col
#
#
#
# landunit_varcon
#
#   istice
#
#   istice_mec
#
#   istsoil
#
#   istcrop
#
#   istwet
#
#
#
# column_varcon
#
#   icol_roof
#
#   icol_sunwall
#
#   icol_shadewall
#
#   icol_road_perv
#
#   icol_road_imperv
#
#
#
# banddiagonalmod
#
#   banddiagonal
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevlak
#
#   nlevurb
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# elm_varctl
#
#   use_vancouver
#
#   use_mexicocity
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# landunit_varcon
#
#   istsoil
#
#   istcrop
#
#   istdlak
#
#   istice
#
#   istice_mec
#
#
#
# elm_varcon
#
#   grlnd
#
#   namep
#
#   namet
#
#   tfrz
#
#   omegas
#
#   betads
#
#   betais
#
#
#
# elm_varpar
#
#   numrad
#
#   nlevcan
#
#   nlevsno
#
#
#
# elm_varctl
#
#   fsurdat
#
#   iulog
#
#   subgridflag
#
#   use_snicar_frc
#
#   use_fates
#
#   use_snicar_ad
#
#
#
# vegetationpropertiestype
#
#   veg_vp
#
#
#
# snowsnicarmod
#
#   sno_nbr_aer
#
#   snicar_rt
#
#   snicar_ad_rt
#
#   do_sno_aer
#
#   do_sno_oc
#
#
#
# aerosoltype
#
#   aerosol_type
#
#
#
# canopystatetype
#
#   canopystate_type
#
#
#
# lakestatetype
#
#   lakestate_type
#
#
#
# surfacealbedotype
#
#   surfalb_type
#
#   lake_melt_icealb
#
#   alblak
#
#   alblakwi
#
#   albice
#
#   albsat
#
#   albdry
#
#   isoicol
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_es
#
#   col_ws
#
#
#
# vegetationtype
#
#   veg_pp
#
#
#
# vegetationdatatype
#
#   veg_es
#
#   veg_ws
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# topounittype
#
#   top_pp
#
#
#
# shr_orb_mod
#
#   all
#
# lakecon
#
#   lakepuddling
#
#
#
# domainmod
#
#   ldomain
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varctl
#
#   iulog
#
#   use_extrasnowlayers
#
#   fsnowoptics
#
#   fsnowaging
#
#
#
# elm_varcon
#
#   namec
#
#   spval
#
#
#
# shr_const_mod
#
#   shr_const_rhoice
#
#   shr_const_pi
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# aerosolmod
#
#   snw_rds_min
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# landunittype
#
#   lun_pp
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_es
#
#   col_ws
#
#   col_wf
#
#
#
# timeinfomod
#
#   all
#
# elm_varpar
#
#   nlevsno
#
#   numrad
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   nlevsno
#
#
#
# elm_varctl
#
#   use_extrasnowlayers
#
#
#
# atm2lndtype
#
#   atm2lnd_type
#
#
#
# aerosoltype
#
#   aerosol_type
#
#
#
# columntype
#
#   col_pp
#
#
#
# columndatatype
#
#   col_ws
#
#   col_wf
#
#
#
# timeinfomod
#
#   all
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# elm_varpar
#
#   nlevsno
#
#   nlevgrnd
#
#   nlevsoi
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varcon
#
#   spval
#
#   ispval
#
#
#
# elm_varctl
#
#   iulog
#
#
#
# shr_kind_mod
#
#   r8 => shr_kind_r8
#
#
#
# decompmod
#
#   bounds_type
#
#
#
# elm_varpar
#
#   numrad
#
#   nlevcan
#
#   nlevsno
#
#
#
# elm_varctl
#
#   fsurdat
#
#   iulog
#
#   use_snicar_frc
#
#
#
# elm_varcon
#
#   grlnd
#
#   spval
#
#   ispval
#
#
#
# columntype
#
#   col_pp
#
#
#
# topounit_varcon
#
#   max_topounits
#
#
#
# gridcelltype
#
#   grc_pp
#
#
#
# shr_kind_mod
#
#   shr_kind_r8
#
#   shr_kind_in
#
#
#
# shr_const_mod
#
#   all

# %%
print(len(mod_dict), len(type_dict))
# Out:
# 60 57

# %%
# from contextlib import redirect_stdout
def get_types():
    with open('out.txt', 'w') as f:
        for dtype in type_dict.keys():
            type_dict[dtype].print_derived_type(ofile=f, long=True)

# %%
type_dict["column_carbon_state"].declaration
# Out:
# 'columndatatype'

# %%
import csv
cols = ["module", "type_name", "members", "member_type", "dim", "bounds", "active"]
with open("der.csv",'w') as file: 
    writer = csv.writer(file, delimiter=',')
    writer.writerow([col for col in cols])
    
    for dtype in type_dict.keys():
        module = type_dict[dtype].declaration
        type_name = type_dict[dtype].type_name
        for comp in type_dict[dtype].components:
            member = comp['var']
            status = comp['active']
            
            bounds = comp['bounds'] if member.dim > 0 else ""
            
            writer.writerow([module, type_name, member.name, member.type, str(member.dim), bounds.strip(), status])

# %%
import csv
cols = ["id", "module", "type_name", "members", "member_type", "dim", "bounds"]
with open("der.csv",'w') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerow([col for col in cols])

# %%
def write_to_csv(csv_file, cols, read_from_file):
    with open(csv_file, "w") as file:
        writer = csv.writer(file, delimiter=",")
        writer.writerow([col for col in cols])
        # with open(read_from_file, "r"):

# %%
mod_dict["laketemperaturemod"].print_module_info()
# Out:
# Module Name: laketemperaturemod biogeophys/LakeTemperatureMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use ch4mod-> ch4_type,
# use energyfluxtype-> energyflux_type,
# use lakestatetype-> lakestate_type,
# use soilstatetype-> soilstate_type,
# use solarabsorbedtype-> solarabs_type,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ef, col_ws, col_wf,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_ef,
# use timeinfomod-> all
# use lakecon-> betavis, za_lake, n2min, tdmax, pudz, depthcrit, mixfact, lakepuddling, lake_no_ed,
# use qsatmod-> qsat,
# use tridiagonalmod-> tridiagonal,
# use elm_varpar-> nlevlak, nlevgrnd, nlevsno, nlevsoi,
# use elm_varcon-> hfus, cpliq, cpice, tkwat, tkice, denice, vkc, grav, denh2o, tfrz, cnfac, tkair, thk_bedrock,
# use elm_varctl-> iulog, use_lch4,
# Variables:
# User Types:

# %%
with open ("mod.csv", 'w') as file:
    writer = csv.writer(file, delimiter=",")
    
for key in mod_dict.keys():
    mod_dict[key].print_module_info()
# Out:
# Module Name: laketemperaturemod biogeophys/LakeTemperatureMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use ch4mod-> ch4_type,
# use energyfluxtype-> energyflux_type,
# use lakestatetype-> lakestate_type,
# use soilstatetype-> soilstate_type,
# use solarabsorbedtype-> solarabs_type,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ef, col_ws, col_wf,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_ef,
# use timeinfomod-> all
# use lakecon-> betavis, za_lake, n2min, tdmax, pudz, depthcrit, mixfact, lakepuddling, lake_no_ed,
# use qsatmod-> qsat,
# use tridiagonalmod-> tridiagonal,
# use elm_varpar-> nlevlak, nlevgrnd, nlevsno, nlevsoi,
# use elm_varcon-> hfus, cpliq, cpice, tkwat, tkice, denice, vkc, grav, denh2o, tfrz, cnfac, tkair, thk_bedrock,
# use elm_varctl-> iulog, use_lch4,
# Variables:
# User Types:
# Module Name: shr_kind_mod util/shr_kind_mod.F90
# Module Depedencies:
# Variables:
# integer shr_kind_r8 0-D True
# integer shr_kind_r4 0-D False
# integer shr_kind_rn 0-D False
# integer shr_kind_i8 0-D False
# integer shr_kind_i4 0-D False
# integer shr_kind_i2 0-D False
# integer shr_kind_in 0-D False
# integer shr_kind_cs 0-D False
# integer shr_kind_cm 0-D False
# integer shr_kind_cl 0-D False
# integer shr_kind_cx 0-D False
# integer shr_kind_cxx 0-D False
# User Types:
# Module Name: decompmod main/decompMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> integer iulog 0-D True,
# use elm_varcon-> character grlnd 0-D False, character nameg 0-D False, character namet 0-D False, character namel 0-D False, character namec 0-D False, character namep 0-D False, character namecohort 0-D False,
# use domainmod-> domain_type ldomain 0-D False,
# Variables:
# integer clump_pproc 0-D False
# integer bounds_subgrid_gridcell 0-D False
# integer bounds_subgrid_topounit 0-D False
# integer bounds_subgrid_landunit 0-D False
# integer bounds_subgrid_column 0-D False
# integer bounds_subgrid_patch 0-D False
# integer bounds_subgrid_cohort 0-D False
# integer bounds_level_proc 0-D False
# integer bounds_level_clump 0-D False
# integer nclumps 0-D False
# integer numg 0-D False
# integer numt 0-D False
# integer numl 0-D False
# integer numc 0-D False
# integer nump 0-D False
# integer numcohort 0-D False
# processor_type procinfo 0-D False
# clump_type clumps 1-D False
# decomp_type ldecomp 0-D False
# User Types:
# DerivedType(bounds_type)
# DerivedType(processor_type)
# DerivedType(clump_type)
# DerivedType(decomp_type)
# Module Name: domainmod utils/domainMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> integer iulog 0-D True,
# Variables:
# domain_type ldomain 0-D False
# real lon1d 1-D False
# real lat1d 1-D False
# User Types:
# DerivedType(domain_type)
# Module Name: ch4mod biogeochem/CH4Mod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer nlevsoi 0-D True, integer ngases 0-D False, integer nlevsno 0-D True, integer nlevdecomp 0-D False, integer nlevgrnd 0-D True, integer nlevdecomp_full 0-D False,
# use elm_varcon-> real denh2o 0-D True, real denice 0-D True, real tfrz 0-D True, real grav 0-D True, real spval 0-D True, real rgas 0-D False, character grlnd 0-D False, real catomw 0-D False, real s_con 2-D False, real d_con_w 2-D False, real d_con_g 2-D False, real c_h_inv 1-D False, real kh_theta 1-D False, real kh_tbase 0-D False, real secspday 0-D False, real rpi 0-D False,
# use landunit_varcon-> integer istdlak 0-D True, integer istsoil 0-D True, integer istcrop 0-D True,
# use elm_varctl-> integer iulog 0-D True, logical use_cn 0-D False, logical use_lch4 0-D True, logical use_fates 0-D True, logical hist_wrtch4diag 0-D False, character fsurdat 0-D False, logical anoxia 0-D False,
# use decompmod-> bounds_type,
# use sharedparamsmod-> paramssharetype paramsshareinst 0-D False, integer nlev_soildecomp_standard 0-D False,
# use atm2lndtype-> atm2lnd_type,
# use canopystatetype-> canopystate_type,
# use energyfluxtype-> energyflux_type,
# use lakestatetype-> lakestate_type,
# use lnd2atmtype-> lnd2atm_type,
# use soilhydrologytype-> soilhydrology_type,
# use soilstatetype-> soilstate_type,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# use topounitdatatype-> topounit_atmospheric_state top_as 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use columndatatype-> column_energy_state col_es 0-D False, column_water_state col_ws 0-D False, column_water_flux col_wf 0-D False, column_carbon_flux col_cf 0-D False, column_nitrogen_flux col_nf 0-D False,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# use vegetationdatatype-> vegetation_water_flux veg_wf 0-D False, vegetation_carbon_state veg_cs 0-D False, vegetation_carbon_flux veg_cf 0-D False,
# use timeinfomod-> all
# use topounit_varcon-> integer max_topounits 0-D False,
# use ch4varcon-> logical allowlakeprod 0-D False, logical usephfact 0-D False, logical fin_use_fsat 0-D False, logical use_aereoxid_prog 0-D False, logical replenishlakec 0-D False, logical ch4offline 0-D False, logical transpirationloss 0-D False, logical usefrootc 0-D False, logical ch4frzout 0-D False,
# use pftvarcon-> integer noveg 0-D False, integer nc3_arctic_grass 0-D False, real crop 1-D False, integer nc3_nonarctic_grass 0-D False, integer nc4_grass 0-D False,
# use lakecon-> all
# use tridiagonalmod-> tridiagonal,
# Variables:
# real rgasm 0-D False
# real rgaslatm 0-D False
# ch4paramstype ch4paramsinst 0-D False
# User Types:
# DerivedType(ch4paramstype)
# DerivedType(ch4_type)
# Module Name: landunit_varcon main/landunit_varcon.F90
# Module Depedencies:
# Variables:
# integer istsoil 0-D True
# integer istcrop 0-D True
# integer istice 0-D True
# integer istice_mec 0-D True
# integer istdlak 0-D True
# integer istwet 0-D True
# integer isturb_min 0-D False
# integer isturb_tbd 0-D False
# integer isturb_hd 0-D False
# integer isturb_md 0-D False
# integer isturb_max 0-D False
# integer max_lunit 0-D False
# integer landunit_name_length 0-D False
# character landunit_names 1-D False
# integer numurbl 0-D False
# User Types:
# Module Name: sharedparamsmod biogeochem/SharedParamsMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# Variables:
# paramssharetype paramsshareinst 0-D False
# logical anoxia_wtsat 0-D False
# integer nlev_soildecomp_standard 0-D False
# User Types:
# DerivedType(paramssharetype)
# Module Name: atm2lndtype main/atm2lndType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer numrad 0-D True, integer ndst 0-D False, integer nlevgrnd 0-D True,
# use elm_varcon-> real rair 0-D False, real grav 0-D True, real cpair 0-D False, real hfus 0-D True, real tfrz 0-D True, real spval 0-D True,
# use elm_varctl-> integer iulog 0-D True, logical use_c13 0-D False, logical use_cn 0-D False, logical use_lch4 0-D True, logical use_fates 0-D True,
# use decompmod-> bounds_type,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# Variables:
# User Types:
# DerivedType(atm2lnd_type)
# Module Name: canopystatetype biogeophys/CanopyStateType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use landunit_varcon-> integer istsoil 0-D True, integer istcrop 0-D True,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# use elm_varpar-> integer nlevcan 0-D True, integer nvegwcs 0-D False, integer nlevgrnd 0-D True,
# use elm_varctl-> integer iulog 0-D True, logical use_cn 0-D False, logical use_fates 0-D True, logical use_hydrstress 0-D False, logical use_fates_sp 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# Variables:
# logical perchroot 0-D False
# logical perchroot_alt 0-D False
# User Types:
# DerivedType(canopystate_type)
# Module Name: lnd2atmtype main/lnd2atmType.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varpar-> numrad, ndst, nlevsno, nlevgrnd,
# use elm_varcon-> rair, grav, cpair, hfus, tfrz, spval,
# use elm_varctl-> iulog, use_c13, use_cn, use_lch4,
# use decompmod-> bounds_type,
# Variables:
# User Types:
# DerivedType(lnd2atm_type)
# Module Name: soilhydrologytype biogeophys/SoilHydrologyType.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varpar-> nlevgrnd, nlayer, nlayert, nlevsoi, more_vertlayers, nlevsoifl, toplev_equalspace, nlevsno, crop_prog, nlevlak, nlevurb,
# use elm_varcon-> zsoi, dzsoi, zisoi, spval, denice, denh2o, sb, bdsno, h2osno_max, zlnd, tfrz, pc, nlvic, dzvic, mu, grlnd,
# use elm_varctl-> iulog, create_glacier_mec_landunit, use_cn, use_lch4, fsurdat, use_vichydro, use_var_soil_thick,
# use sharedparamsmod-> paramsshareinst,
# use landunittype-> lun_pp,
# use columntype-> col_pp,
# use gridcelltype-> grc_pp,
# use topounit_varcon-> max_topounits,
# use shr_const_mod-> shr_const_pi, shr_const_tkfrz,
# use shr_spfn_mod-> shr_spfn_erf,
# use landunit_varcon-> istice, istwet, istsoil, istdlak, istcrop, istice_mec,
# use column_varcon-> icol_shadewall, icol_road_perv, icol_road_imperv, icol_roof, icol_sunwall,
# Variables:
# User Types:
# DerivedType(soilhydrology_type)
# Module Name: shr_const_mod util/shr_const_mod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# Variables:
# real shr_const_pi 0-D True
# real shr_const_cday 0-D False
# real shr_const_sday 0-D False
# real shr_const_omega 0-D False
# real shr_const_rearth 0-D False
# real shr_const_g 0-D False
# real shr_const_stebol 0-D False
# real shr_const_boltz 0-D False
# real shr_const_avogad 0-D False
# real shr_const_rgas 0-D False
# real shr_const_mwdair 0-D False
# real shr_const_mwwv 0-D False
# real shr_const_rdair 0-D False
# real shr_const_rwv 0-D False
# real shr_const_zvir 0-D False
# real shr_const_karman 0-D False
# real shr_const_pstd 0-D False
# real shr_const_pdb 0-D False
# real shr_const_tktrip 0-D False
# real shr_const_tkfrz 0-D False
# real shr_const_tkfrzsw 0-D False
# real shr_const_zsrflyr 0-D False
# real shr_const_rhodair 0-D False
# real shr_const_rhofw 0-D False
# real shr_const_rhosw 0-D False
# real shr_const_rhoice 0-D False
# real shr_const_cpdair 0-D False
# real shr_const_cpwv 0-D False
# real shr_const_cpvir 0-D False
# real shr_const_cpfw 0-D False
# real shr_const_cpsw 0-D False
# real shr_const_cpice 0-D False
# real shr_const_latice 0-D False
# real shr_const_latvap 0-D False
# real shr_const_latsub 0-D False
# real shr_const_condice 0-D False
# real shr_const_kappa_land_ice 0-D False
# real shr_const_tf0 0-D False
# real shr_const_dtf_dp 0-D False
# real shr_const_dtf_ds 0-D False
# real shr_const_dtf_dpds 0-D False
# real shr_const_ocn_ref_sal 0-D False
# real shr_const_ice_ref_sal 0-D False
# real shr_const_spval 0-D False
# real shr_const_spval_tolmin 0-D False
# real shr_const_spval_tolmax 0-D False
# real shr_const_spval_aerodep 0-D False
# real shr_const_vsmow_18o 0-D False
# real shr_const_vsmow_17o 0-D False
# real shr_const_vsmow_16o 0-D False
# real shr_const_vsmow_d 0-D False
# real shr_const_vsmow_t 0-D False
# real shr_const_vsmow_h 0-D False
# real shr_const_rstd_h2odev 0-D False
# User Types:
# Module Name: shr_spfn_mod util/shr_spfn_mod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r4, shr_kind_r8,
# use shr_const_mod-> shr_const_pi,
# Variables:
# integer r4 0-D False
# integer r8 0-D False
# real pi 0-D False
# real sqrtpi 0-D False
# real epsr8 0-D False
# real xinfr8 0-D False
# real xminr8 0-D False
# real xsmallr8 0-D False
# real xmaxr8 0-D False
# real epsr4 0-D False
# real xinfr4 0-D False
# real xminr4 0-D False
# real xsmallr4 0-D False
# real xmaxr4 0-D False
# real xbig_gamma 0-D False
# User Types:
# Module Name: column_varcon main/column_varcon.F90
# Module Depedencies:
# use landunit_varcon-> integer isturb_min 0-D False, integer istsoil 0-D True, integer istcrop 0-D True, integer istice_mec 0-D True,
# use elm_varpar-> integer maxpatch_glcmec 0-D False,
# Variables:
# integer icol_roof 0-D True
# integer icol_sunwall 0-D True
# integer icol_shadewall 0-D True
# integer icol_road_imperv 0-D True
# integer icol_road_perv 0-D True
# User Types:
# Module Name: gridcelltype data_types/GridcellType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use landunit_varcon-> integer max_lunit 0-D False,
# use elm_varcon-> integer ispval 0-D False, real spval 0-D True,
# use topounit_varcon-> integer max_topounits 0-D False,
# Variables:
# gridcell_physical_properties_type grc_pp 0-D False
# User Types:
# DerivedType(gridcell_physical_properties_type)
# Module Name: topounitdatatype data_types/TopounitDataType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# use elm_varctl-> integer iulog 0-D True, logical use_cn 0-D False, logical use_fates 0-D True, logical use_lch4 0-D True,
# use elm_varpar-> integer numrad 0-D True,
# use decompmod-> bounds_type,
# use topounittype-> topounit_physical_properties top_pp 0-D False,
# Variables:
# topounit_atmospheric_state top_as 0-D False
# topounit_atmospheric_flux top_af 0-D False
# topounit_energy_state top_es 0-D False
# User Types:
# DerivedType(topounit_atmospheric_state)
# DerivedType(topounit_atmospheric_flux)
# DerivedType(topounit_energy_state)
# Module Name: topounittype data_types/TopounitType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use landunit_varcon-> integer max_lunit 0-D False,
# use elm_varcon-> integer ispval 0-D False, real spval 0-D True,
# use elm_varpar-> integer numrad 0-D True,
# use decompmod-> bounds_type,
# Variables:
# topounit_physical_properties top_pp 0-D False
# User Types:
# DerivedType(topounit_physical_properties)
# Module Name: landunittype data_types/LandunitType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> integer ispval 0-D False, real spval 0-D True,
# Variables:
# landunit_physical_properties lun_pp 0-D False
# User Types:
# DerivedType(landunit_physical_properties)
# Module Name: topounit_varcon main/topounit_varcon.F90
# Module Depedencies:
# use elm_varctl-> character fsurdat 0-D False, integer iulog 0-D True,
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> character grlnd 0-D False,
# use domainmod-> domain_type,
# Variables:
# integer max_topounits 0-D False
# logical has_topounit 0-D False
# User Types:
# Module Name: ch4varcon biogeochem/CH4varcon.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varctl-> iulog, nlfilename_in,
# Variables:
# logical use_aereoxid_prog 0-D False
# logical transpirationloss 0-D False
# logical allowlakeprod 0-D False
# logical usephfact 0-D False
# logical replenishlakec 0-D False
# logical fin_use_fsat 0-D False
# logical usefrootc 0-D False
# logical ch4offline 0-D False
# logical ch4rmcnlim 0-D False
# logical anoxicmicrosites 0-D False
# logical ch4frzout 0-D False
# User Types:
# Module Name: pftvarcon main/pftvarcon.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varpar-> mxpft, numrad, ivis, inir, cft_lb, cft_ub, mxpft_nc, nlevdecomp_full, nsoilorder,
# use elm_varctl-> iulog, use_vertsoilc, nu_com, paramfile, use_fates, use_crop, use_dynroot,
# use elm_varcon-> tfrz,
# Variables:
# integer noveg 0-D False
# integer ndllf_evr_tmp_tree 0-D False
# integer ndllf_evr_brl_tree 0-D False
# integer ndllf_dcd_brl_tree 0-D False
# integer nbrdlf_evr_trp_tree 0-D False
# integer nbrdlf_evr_tmp_tree 0-D False
# integer nbrdlf_dcd_trp_tree 0-D False
# integer nbrdlf_dcd_tmp_tree 0-D False
# integer nbrdlf_dcd_brl_tree 0-D False
# integer ntree 0-D False
# integer nbrdlf_evr_shrub 0-D False
# integer nbrdlf_dcd_tmp_shrub 0-D False
# integer nbrdlf_dcd_brl_shrub 0-D False
# integer nc3_arctic_grass 0-D False
# integer nc3_nonarctic_grass 0-D False
# integer nc4_grass 0-D False
# integer npcropmin 0-D False
# integer nppercropmin 0-D False
# integer ncorn 0-D False
# integer ncornirrig 0-D False
# integer nscereal 0-D False
# integer nscerealirrig 0-D False
# integer nwcereal 0-D False
# integer nwcerealirrig 0-D False
# integer nsoybean 0-D False
# integer nsoybeanirrig 0-D False
# integer npcropmax 0-D False
# integer nppercropmax 0-D False
# integer nc3crop 0-D False
# integer nc3irrig 0-D False
# integer ncassava 0-D False
# integer ncassavairrig 0-D False
# integer ncotton 0-D False
# integer ncottonirrig 0-D False
# integer nfoddergrass 0-D False
# integer nfoddergrassirrig 0-D False
# integer noilpalm 0-D False
# integer noilpalmirrig 0-D False
# integer nograins 0-D False
# integer nograinsirrig 0-D False
# integer nrapeseed 0-D False
# integer nrapeseedirrig 0-D False
# integer nrice 0-D False
# integer nriceirrig 0-D False
# integer nrtubers 0-D False
# integer nrtubersirrig 0-D False
# integer nsugarcane 0-D False
# integer nsugarcaneirrig 0-D False
# integer nmiscanthus 0-D False
# integer nmiscanthusirrig 0-D False
# integer nswitchgrass 0-D False
# integer nswitchgrassirrig 0-D False
# integer npoplar 0-D False
# integer npoplarirrig 0-D False
# integer nwillow 0-D False
# integer nwillowirrig 0-D False
# integer num_cfts_known_to_model 0-D False
# real dleaf 1-D False
# real c3psn 1-D False
# real xl 1-D True
# real rhol 2-D True
# real rhos 2-D True
# real taul 2-D True
# real taus 2-D True
# real z0mr 1-D False
# real displar 1-D False
# real roota_par 1-D False
# real rootb_par 1-D False
# real crop 1-D False
# real percrop 1-D False
# real irrigated 1-D False
# real smpso 1-D False
# real smpsc 1-D False
# real fnitr 1-D False
# real slatop 1-D False
# real dsladlai 1-D False
# real leafcn 1-D False
# real flnr 1-D False
# real woody 1-D False
# real lflitcn 1-D False
# real frootcn 1-D False
# real livewdcn 1-D False
# real deadwdcn 1-D False
# real grperc 1-D False
# real grpnow 1-D False
# real rootprof_beta 1-D False
# real leafcp 1-D False
# real lflitcp 1-D False
# real frootcp 1-D False
# real livewdcp 1-D False
# real deadwdcp 1-D False
# integer mergetoelmpft 1-D False
# logical is_pft_known_to_model 1-D False
# real graincn 1-D False
# real graincp 1-D False
# real mxtmp 1-D False
# real baset 1-D False
# real declfact 1-D False
# real bfact 1-D False
# real aleaff 1-D False
# real arootf 1-D False
# real astemf 1-D False
# real arooti 1-D False
# real fleafi 1-D False
# real allconsl 1-D False
# real allconss 1-D False
# real ztopmx 1-D False
# real laimx 1-D False
# real gddmin 1-D False
# real hybgdd 1-D False
# real lfemerg 1-D False
# real grnfill 1-D False
# integer mxmat 1-D False
# integer mnnhplantdate 1-D False
# integer mxnhplantdate 1-D False
# integer mnshplantdate 1-D False
# integer mxshplantdate 1-D False
# real planttemp 1-D False
# real minplanttemp 1-D False
# real senestemp 1-D False
# real min_days_senes 1-D False
# real froot_leaf 1-D False
# real stem_leaf 1-D False
# real croot_stem 1-D False
# real flivewd 1-D False
# real fcur 1-D False
# real lf_flab 1-D False
# real lf_fcel 1-D False
# real lf_flig 1-D False
# real fr_flab 1-D False
# real fr_fcel 1-D False
# real fr_flig 1-D False
# real leaf_long 1-D False
# real froot_long 1-D False
# real evergreen 1-D False
# real stress_decid 1-D False
# real season_decid 1-D False
# real pconv 1-D False
# real pprod10 1-D False
# real pprod100 1-D False
# real pprodharv10 1-D False
# real cc_leaf 1-D False
# real cc_lstem 1-D False
# real cc_dstem 1-D False
# real cc_other 1-D False
# real fm_leaf 1-D False
# real fm_lstem 1-D False
# real fm_dstem 1-D False
# real fm_other 1-D False
# real fm_root 1-D False
# real fm_lroot 1-D False
# real fm_droot 1-D False
# real fsr_pft 1-D False
# real fd_pft 1-D False
# real fertnitro 1-D False
# real fleafcn 1-D False
# real ffrootcn 1-D False
# real fstemcn 1-D False
# real presharv 1-D False
# real convfact 1-D False
# real fyield 1-D False
# real root_dmx 1-D False
# integer pftname_len 0-D False
# character pftname 1-D False
# real reinickerp 0-D False
# real dwood 0-D False
# real allom1 0-D False
# real allom2 0-D False
# real allom3 0-D False
# real allom1s 0-D False
# real allom2s 0-D False
# real vmax_plant_nh4 1-D False
# real vmax_plant_no3 1-D False
# real vmax_plant_p 1-D False
# real vmax_minsurf_p_vr 2-D False
# real km_plant_nh4 1-D False
# real km_plant_no3 1-D False
# real km_plant_p 1-D False
# real km_minsurf_p_vr 2-D False
# real km_decomp_nh4 0-D False
# real km_decomp_no3 0-D False
# real km_decomp_p 0-D False
# real km_nit 0-D False
# real km_den 0-D False
# real decompmicc_patch_vr 2-D False
# real alpha_nfix 1-D False
# real alpha_ptase 1-D False
# real ccost_nfix 1-D False
# real pcost_nfix 1-D False
# real ccost_ptase 1-D False
# real ncost_ptase 1-D False
# real vmax_nfix 1-D False
# real km_nfix 1-D False
# real vmax_ptase 1-D False
# real km_ptase 0-D False
# real lamda_ptase 0-D False
# real i_vc 1-D False
# real s_vc 1-D False
# real nsc_rtime 1-D False
# real pinit_beta1 1-D False
# real pinit_beta2 1-D False
# real leafcn_obs 1-D False
# real frootcn_obs 1-D False
# real livewdcn_obs 1-D False
# real deadwdcn_obs 1-D False
# real leafcp_obs 1-D False
# real frootcp_obs 1-D False
# real livewdcp_obs 1-D False
# real deadwdcp_obs 1-D False
# real leafcn_obs_flex 2-D False
# real frootcn_obs_flex 2-D False
# real livewdcn_obs_flex 2-D False
# real deadwdcn_obs_flex 2-D False
# real leafcp_obs_flex 2-D False
# real frootcp_obs_flex 2-D False
# real livewdcp_obs_flex 2-D False
# real deadwdcp_obs_flex 2-D False
# real fnr 1-D False
# real act25 1-D False
# real kcha 1-D False
# real koha 1-D False
# real cpha 1-D False
# real vcmaxha 1-D False
# real jmaxha 1-D False
# real tpuha 1-D False
# real lmrha 1-D False
# real vcmaxhd 1-D False
# real jmaxhd 1-D False
# real tpuhd 1-D False
# real lmrhd 1-D False
# real lmrse 1-D False
# real qe 1-D False
# real theta_cj 1-D False
# real bbbopt 1-D False
# real mbbopt 1-D False
# real nstor 1-D False
# real br_xr 1-D False
# real tc_stress 0-D False
# real vcmax_np1 1-D False
# real vcmax_np2 1-D False
# real vcmax_np3 1-D False
# real vcmax_np4 1-D False
# real jmax_np1 0-D False
# real jmax_np2 0-D False
# real jmax_np3 0-D False
# real laimax 0-D False
# real rsub_top_globalmax 0-D False
# real gcpsi 1-D False
# real pftcc 1-D False
# User Types:
# Module Name: energyfluxtype biogeophys/EnergyFluxType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> real spval 0-D True, real denice 0-D True, real denh2o 0-D True, real sb 0-D True,
# use decompmod-> bounds_type,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# use annualfluxdribbler-> annual_flux_dribbler_type, annual_flux_dribbler_gridcell,
# use elm_varpar-> integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, logical crop_prog 0-D False, integer nlevsoi 0-D True, integer nlevurb 0-D True,
# use elm_varctl-> logical use_cn 0-D False, integer iulog 0-D True, logical use_vancouver 0-D False, logical use_mexicocity 0-D False,
# use shr_const_mod-> real shr_const_tkfrz 0-D False,
# use landunit_varcon-> integer istice 0-D True, integer istwet 0-D True, integer istsoil 0-D True, integer istdlak 0-D True, integer istice_mec 0-D True,
# use column_varcon-> integer icol_road_imperv 0-D True, integer icol_roof 0-D True, integer icol_sunwall 0-D True, integer icol_shadewall 0-D True, integer icol_road_perv 0-D True,
# Variables:
# User Types:
# DerivedType(energyflux_type)
# Module Name: annualfluxdribbler utils/AnnualFluxDribbler.F90
# Module Depedencies:
# use elm_varctl-> iulog,
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type, get_beg, get_end, bounds_subgrid_gridcell, bounds_subgrid_patch,
# use elm_varcon-> secspday, nameg, namep,
# Variables:
# integer name_maxlen 0-D False
# integer units_maxlen 0-D False
# integer subgrid_maxlen 0-D False
# character sourcefile 0-D False
# User Types:
# DerivedType(annual_flux_dribbler_type)
# Module Name: lakestatetype biogeophys/LakeStateType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> real spval 0-D True, character grlnd 0-D False, real tkwat 0-D True,
# use decompmod-> bounds_type,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use elm_varpar-> integer nlevlak 0-D True, integer nlevsno 0-D True,
# use elm_varctl-> character fsurdat 0-D False, integer iulog 0-D True,
# Variables:
# User Types:
# DerivedType(lakestate_type)
# Module Name: soilstatetype biogeophys/SoilStateType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varpar-> logical more_vertlayers 0-D False, integer numpft 0-D False, integer numrad 0-D True, integer nlevsoi 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, integer nlevsoifl 0-D False, integer nlayer 0-D False, integer nlayert 0-D False, integer nlevurb 0-D True, integer nlevsno 0-D True,
# use landunit_varcon-> integer istice 0-D True, integer istdlak 0-D True, integer istwet 0-D True, integer istsoil 0-D True, integer istcrop 0-D True, integer istice_mec 0-D True, integer max_lunit 0-D False,
# use column_varcon-> integer icol_roof 0-D True, integer icol_sunwall 0-D True, integer icol_shadewall 0-D True, integer icol_road_perv 0-D True, integer icol_road_imperv 0-D True,
# use elm_varcon-> real zsoi 1-D False, real dzsoi 1-D False, real zisoi 1-D False, real spval 0-D True, character namet 0-D False, character grlnd 0-D False, real secspday 0-D False, real pc 0-D False, real mu 0-D True, real denh2o 0-D True, real denice 0-D True,
# use elm_varctl-> logical use_cn 0-D False, logical use_lch4 0-D True, logical use_dynroot 0-D False, logical use_fates 0-D True, logical use_erosion 0-D False, logical use_var_soil_thick 0-D False, integer iulog 0-D True, character fsurdat 0-D False, logical hist_wrtch4diag 0-D False, logical use_hydrstress 0-D False,
# use ch4varcon-> logical allowlakeprod 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# use topounit_varcon-> integer max_topounits 0-D False,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# use pftvarcon-> integer noveg 0-D False, real roota_par 1-D False, real rootb_par 1-D False,
# use sharedparamsmod-> paramssharetype paramsshareinst 0-D False,
# use funcpedotransfermod-> pedotransf, get_ipedof,
# use rootbiophysmod-> init_vegrootfr,
# use domainlateralmod-> exchangecolumnlevelghostdata,
# Variables:
# User Types:
# DerivedType(soilstate_type)
# Module Name: funcpedotransfermod main/FuncPedotransferMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# Variables:
# integer cosby_1984_table5 0-D False
# integer cosby_1984_table4 0-D False
# integer noilhan_lacarrere_1995 0-D False
# integer ipedof0 0-D False
# User Types:
# Module Name: rootbiophysmod biogeophys/RootBiophysMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use pftvarcon-> noveg, roota_par, rootb_par,
# use elm_varctl-> use_var_soil_thick,
# use vegetationtype-> veg_pp,
# use columntype-> col_pp,
# Variables:
# integer zeng_2001_root 0-D False
# integer root_prof_method 0-D False
# User Types:
# Module Name: domainlateralmod utils/domainLateralMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varctl-> iulog,
# use decompmod-> ldecomp, get_proc_bounds, bounds_type, bounds_level_proc,
# use landunit_varcon-> max_lunit,
# use landunittype-> lun_pp,
# use columntype-> col_pp,
# Variables:
# domainlateral_type ldomain_lateral 0-D False
# User Types:
# DerivedType(domainlateral_type)
# Module Name: solarabsorbedtype biogeophys/SolarAbsorbedType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varcon-> real spval 0-D True,
# use elm_varpar-> integer nlevcan 0-D True, integer numrad 0-D True, integer nlevsno 0-D True,
# use elm_varctl-> logical use_snicar_frc 0-D True, integer iulog 0-D True,
# use landunit_varcon-> integer istsoil 0-D True, integer istcrop 0-D True,
# Variables:
# User Types:
# DerivedType(solarabs_type)
# Module Name: columntype data_types/ColumnType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, integer nlevslp 0-D False,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# Variables:
# column_physical_properties col_pp 0-D False
# User Types:
# DerivedType(column_physical_properties)
# Module Name: columndatatype data_types/ColumnDataType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use shr_const_mod-> real shr_const_tkfrz 0-D False, real shr_const_pdb 0-D False,
# use elm_varpar-> integer nlevsoi 0-D True, integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, integer nlevurb 0-D True, integer ndecomp_cascade_transitions 0-D False, integer ndecomp_pools 0-D False, integer nlevcan 0-D True, integer nlevdecomp_full 0-D False, logical crop_prog 0-D False, integer nlevdecomp 0-D False, integer i_met_lit 0-D False, integer i_cel_lit 0-D False, integer i_lig_lit 0-D False, integer i_cwd 0-D False,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False, real zlnd 0-D False, real snw_rds_min 0-D False, real denice 0-D True, real denh2o 0-D True, real tfrz 0-D True, real pondmx 0-D False, real watmin 0-D False, real bdsno 0-D False, real zsoi 1-D False, real zisoi 1-D False, real dzsoi_decomp 1-D False, real c13ratio 0-D False, real c14ratio 0-D False, real secspday 0-D False,
# use elm_varctl-> logical use_fates 0-D True, logical use_fates_planthydro 0-D False, logical create_glacier_mec_landunit 0-D False, logical use_hydrstress 0-D False, logical bound_h2osoi 0-D False, logical use_cn 0-D False, integer iulog 0-D True, logical use_vertsoilc 0-D False, integer spinup_state 0-D False, logical use_erosion 0-D False, logical use_elm_interface 0-D False, logical use_pflotran 0-D False, logical pf_cmode 0-D False, logical hist_wrtch4diag 0-D False, logical use_century_decomp 0-D False, get_carbontag, logical override_bgc_restart_mismatch_dump 0-D False, logical pf_hmode 0-D False, character nu_com 0-D False, logical use_vancouver 0-D False, logical use_mexicocity 0-D False, logical use_lake_wat_storage 0-D False,
# use ch4varcon-> logical allowlakeprod 0-D False,
# use pftvarcon-> real vmax_minsurf_p_vr 2-D False, real km_minsurf_p_vr 2-D False, real pinit_beta1 1-D False, real pinit_beta2 1-D False,
# use soilorder_varcon-> real smax 1-D False, real ks_sorption 1-D False,
# use landunit_varcon-> integer istice 0-D True, integer istwet 0-D True, integer istsoil 0-D True, integer istdlak 0-D True, integer istcrop 0-D True, integer istice_mec 0-D True,
# use column_varcon-> integer icol_road_perv 0-D True, integer icol_road_imperv 0-D True, integer icol_roof 0-D True, integer icol_sunwall 0-D True, integer icol_shadewall 0-D True,
# use decompmod-> bounds_type,
# use cnstatetype-> cnstate_type,
# use cndecompcascadecontype-> decomp_cascade_type decomp_cascade_con 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use urbanparamstype-> urbanparams_type urbanparams_vars 0-D False,
# Variables:
# real nfix_timeconst 0-D False
# column_energy_state col_es 0-D False
# column_water_state col_ws 0-D False
# column_carbon_state col_cs 0-D False
# column_carbon_state c13_col_cs 0-D False
# column_carbon_state c14_col_cs 0-D False
# column_nitrogen_state col_ns 0-D False
# column_phosphorus_state col_ps 0-D False
# column_energy_flux col_ef 0-D False
# column_water_flux col_wf 0-D False
# column_carbon_flux col_cf 0-D False
# column_carbon_flux c13_col_cf 0-D False
# column_carbon_flux c14_col_cf 0-D False
# column_nitrogen_flux col_nf 0-D False
# column_phosphorus_flux col_pf 0-D False
# User Types:
# DerivedType(column_energy_state)
# DerivedType(column_water_state)
# DerivedType(column_carbon_state)
# DerivedType(column_nitrogen_state)
# DerivedType(column_phosphorus_state)
# DerivedType(column_energy_flux)
# DerivedType(column_water_flux)
# DerivedType(column_carbon_flux)
# DerivedType(column_nitrogen_flux)
# DerivedType(column_phosphorus_flux)
# Module Name: soilorder_varcon main/soilorder_varcon.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varpar-> nsoilorder,
# use elm_varctl-> iulog, use_vertsoilc, fsoilordercon,
# Variables:
# character soilordername 1-D False
# integer water 0-D False
# integer andisols 0-D False
# integer gelisols 0-D False
# integer histosols 0-D False
# integer entisols 0-D False
# integer inceptisols 0-D False
# integer aridsols 0-D False
# integer vertisols 0-D False
# integer mollisols 0-D False
# integer alfisols 0-D False
# integer spodosols 0-D False
# integer ultisols 0-D False
# integer oxisols 0-D False
# integer shifting_sand 0-D False
# integer rock_land 0-D False
# integer ice_glacier 0-D False
# real smax 1-D False
# real ks_sorption 1-D False
# real r_weather 1-D False
# real r_adsorp 1-D False
# real r_desorp 1-D False
# real r_occlude 1-D False
# real k_s1_biochem 1-D False
# real k_s2_biochem 1-D False
# real k_s3_biochem 1-D False
# real k_s4_biochem 1-D False
# real r_mort_soilorder 1-D False
# User Types:
# Module Name: cnstatetype data_types/CNStateType.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varpar-> nlevsno, nlevgrnd, nlevlak, nlevsoifl, nlevsoi, crop_prog, ndecomp_cascade_transitions, nlevdecomp, nlevdecomp_full, more_vertlayers,
# use elm_varcon-> spval, ispval, c14ratio, grlnd,
# use landunit_varcon-> istsoil, istcrop,
# use elm_varctl-> use_vertsoilc, use_c14, use_cn, iulog, fsurdat, forest_fert_exp, nu_com, use_fates, use_crop, nsrest, nsrstartup,
# use landunittype-> lun_pp,
# use columntype-> col_pp,
# use vegetationtype-> veg_pp,
# use topounit_varcon-> max_topounits,
# use gridcelltype-> grc_pp,
# Variables:
# integer fert_type 1-D False
# integer fert_continue 1-D False
# real fert_dose 2-D False
# integer fert_start 1-D False
# integer fert_end 1-D False
# User Types:
# DerivedType(cnstate_type)
# Module Name: cndecompcascadecontype biogeochem/CNDecompCascadeConType.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varpar-> ndecomp_cascade_transitions, ndecomp_pools,
# Variables:
# decomp_cascade_type decomp_cascade_con 0-D False
# User Types:
# DerivedType(decomp_cascade_type)
# Module Name: urbanparamstype biogeophys/UrbanParamsType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varctl-> integer iulog 0-D True, character fsurdat 0-D False, logical use_vancouver 0-D False, logical use_mexicocity 0-D False,
# use elm_varcon-> character namel 0-D False, character grlnd 0-D False, real spval 0-D True, real vkc 0-D True,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# use topounit_varcon-> integer max_topounits 0-D False, logical has_topounit 0-D False,
# use elm_varpar-> integer nlevcan 0-D True, integer numrad 0-D True, integer nlevgrnd 0-D True, integer nlevurb 0-D True, integer nlevsoi 0-D True,
# use column_varcon-> integer icol_roof 0-D True, integer icol_sunwall 0-D True, integer icol_shadewall 0-D True, integer icol_road_perv 0-D True, integer icol_road_imperv 0-D True,
# use landunit_varcon-> integer isturb_min 0-D False, integer numurbl 0-D False,
# use domainmod-> domain_type ldomain 0-D False,
# use elm_varsur-> logical urban_valid 2-D False,
# Variables:
# urbinp_type urbinp 0-D False
# character urban_hac_off 0-D False
# character urban_hac_on 0-D False
# character urban_wasteheat_on 0-D False
# character urban_hac 0-D False
# logical urban_traffic 0-D False
# urbanparams_type urbanparams_vars 0-D False
# User Types:
# DerivedType(urbinp_type)
# DerivedType(urbanparams_type)
# Module Name: elm_varsur main/elm_varsur.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# Variables:
# real wt_lunit 3-D False
# logical urban_valid 2-D False
# real wt_nat_patch 3-D False
# real wt_cft 3-D False
# real fert_cft 3-D False
# real wt_glc_mec 3-D False
# real topo_glc_mec 3-D False
# real num_tunit_per_grd 1-D False
# real wt_tunit 2-D False
# real elv_tunit 2-D False
# real slp_tunit 2-D False
# integer asp_tunit 2-D False
# User Types:
# Module Name: vegetationtype data_types/VegetationType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varcon-> integer ispval 0-D False, real spval 0-D True,
# use elm_varctl-> logical use_fates 0-D True,
# Variables:
# vegetation_physical_properties veg_pp 0-D False
# User Types:
# DerivedType(vegetation_physical_properties)
# Module Name: vegetationdatatype data_types/VegetationDataType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use shr_const_mod-> real shr_const_pdb 0-D False, real shr_const_cday 0-D False, real shr_const_tkfrz 0-D False,
# use elm_varpar-> integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, integer nlevurb 0-D True, integer nlevcan 0-D True, logical crop_prog 0-D False, integer nlevdecomp 0-D False, integer nlevdecomp_full 0-D False,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False, real sb 0-D True, real c13ratio 0-D False, real c14ratio 0-D False,
# use landunit_varcon-> integer istsoil 0-D True, integer istcrop 0-D True,
# use pftvarcon-> integer npcropmin 0-D False, integer noveg 0-D False, real nstor 1-D False,
# use elm_varctl-> integer iulog 0-D True, logical use_cn 0-D False, integer spinup_state 0-D False, real spinup_mortality_factor 0-D False, logical use_fates 0-D True, character nu_com 0-D False, logical use_crop 0-D False, logical use_c13 0-D False, logical use_lch4 0-D True, logical use_betr 0-D False, logical use_vancouver 0-D False, logical use_mexicocity 0-D False, integer nsrest 0-D False, integer nsrstartup 0-D False,
# use decompmod-> bounds_type, get_proc_global,
# use subgridavemod-> p2c, p2c_1d_filter,
# use cnstatetype-> cnstate_type,
# use speciesmod-> species_from_string,
# use vegetationtype-> vegetation_physical_properties veg_pp 0-D False,
# use vegetationpropertiestype-> vegetation_properties_type veg_vp 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# use columndatatype-> column_energy_state col_es 0-D False, column_carbon_state, column_carbon_flux, column_nitrogen_state, column_nitrogen_flux, column_phosphorus_state, column_phosphorus_flux,
# Variables:
# vegetation_energy_state veg_es 0-D False
# vegetation_water_state veg_ws 0-D False
# vegetation_carbon_state veg_cs 0-D False
# vegetation_carbon_state c13_veg_cs 0-D False
# vegetation_carbon_state c14_veg_cs 0-D False
# vegetation_nitrogen_state veg_ns 0-D False
# vegetation_phosphorus_state veg_ps 0-D False
# vegetation_energy_flux veg_ef 0-D False
# vegetation_water_flux veg_wf 0-D False
# vegetation_carbon_flux veg_cf 0-D False
# vegetation_carbon_flux c13_veg_cf 0-D False
# vegetation_carbon_flux c14_veg_cf 0-D False
# vegetation_nitrogen_flux veg_nf 0-D False
# vegetation_phosphorus_flux veg_pf 0-D False
# User Types:
# DerivedType(vegetation_energy_state)
# DerivedType(vegetation_water_state)
# DerivedType(vegetation_carbon_state)
# DerivedType(vegetation_nitrogen_state)
# DerivedType(vegetation_phosphorus_state)
# DerivedType(vegetation_energy_flux)
# DerivedType(vegetation_water_flux)
# DerivedType(vegetation_carbon_flux)
# DerivedType(vegetation_nitrogen_flux)
# DerivedType(vegetation_phosphorus_flux)
# Module Name: subgridavemod main/subgridAveMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use column_varcon-> icol_roof, icol_sunwall, icol_shadewall, icol_road_perv, icol_road_imperv,
# use elm_varcon-> grlnd, nameg, namet, namel, namec, namep, spval,
# use elm_varctl-> iulog,
# use decompmod-> bounds_type,
# use topounittype-> top_pp,
# use landunittype-> lun_pp,
# use columntype-> col_pp, column_physical_properties,
# use vegetationtype-> veg_pp,
# use landunit_varcon-> max_lunit, istsoil, istcrop, istice, istice_mec, istdlak, isturb_min, isturb_max,
# Variables:
# integer unity 0-D False
# integer urbanf 0-D False
# integer urbans 0-D False
# integer natveg 0-D False
# integer veg 0-D False
# integer ice 0-D False
# integer nonurb 0-D False
# integer lake 0-D False
# User Types:
# Module Name: speciesmod biogeochem/SpeciesMod.F90
# Module Depedencies:
# Variables:
# integer cn_species_c12 0-D False
# integer cn_species_c13 0-D False
# integer cn_species_c14 0-D False
# integer cn_species_n 0-D False
# integer cn_species_p 0-D False
# User Types:
# Module Name: vegetationpropertiestype data_types/VegetationPropertiesType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer nlevdecomp 0-D False, integer nsoilorder 0-D False, integer numrad 0-D True, integer numpft 0-D False,
# use elm_varctl-> character nu_com 0-D False,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# use pftvarcon-> integer ntree 0-D False, real smpso 1-D False, real smpsc 1-D False, real fnitr 1-D False, real z0mr 1-D False, real displar 1-D False, real dleaf 1-D False, real rhol 2-D True, real rhos 2-D True, real taul 2-D True, real taus 2-D True, real xl 1-D True, real c3psn 1-D False, real slatop 1-D False, real dsladlai 1-D False, real leafcn 1-D False, real flnr 1-D False, real woody 1-D False, real lflitcn 1-D False, real frootcn 1-D False, real livewdcn 1-D False, real deadwdcn 1-D False, real froot_leaf 1-D False, real stem_leaf 1-D False, real croot_stem 1-D False, real flivewd 1-D False, real fcur 1-D False, real lf_flab 1-D False, real lf_fcel 1-D False, real lf_flig 1-D False, real fr_flab 1-D False, real fr_fcel 1-D False, real fr_flig 1-D False, real leaf_long 1-D False, real froot_long 1-D False, real evergreen 1-D False, real stress_decid 1-D False, real season_decid 1-D False, real fertnitro 1-D False, real graincn 1-D False, real fleafcn 1-D False, real ffrootcn 1-D False, real fstemcn 1-D False, real dwood 0-D False, real presharv 1-D False, real convfact 1-D False, real fyield 1-D False, real leafcp 1-D False, real lflitcp 1-D False, real frootcp 1-D False, real livewdcp 1-D False, real deadwdcp 1-D False, real graincp 1-D False, real vmax_plant_nh4 1-D False, real vmax_plant_no3 1-D False, real vmax_plant_p 1-D False, real vmax_minsurf_p_vr 2-D False, real km_plant_nh4 1-D False, real km_plant_no3 1-D False, real km_plant_p 1-D False, real km_minsurf_p_vr 2-D False, real km_decomp_nh4 0-D False, real km_decomp_no3 0-D False, real km_decomp_p 0-D False, real km_nit 0-D False, real km_den 0-D False, real decompmicc_patch_vr 2-D False, real vmax_nfix 1-D False, real km_nfix 1-D False, real alpha_nfix 1-D False, real alpha_ptase 1-D False, real ccost_nfix 1-D False, real ccost_ptase 1-D False, real vmax_ptase 1-D False, real km_ptase 0-D False, real lamda_ptase 0-D False, real i_vc 1-D False, real s_vc 1-D False, real nsc_rtime 1-D False, real pinit_beta1 1-D False, real pinit_beta2 1-D False, real leafcn_obs 1-D False, real frootcn_obs 1-D False, real livewdcn_obs 1-D False, real deadwdcn_obs 1-D False, real leafcp_obs 1-D False, real frootcp_obs 1-D False, real livewdcp_obs 1-D False, real deadwdcp_obs 1-D False, real fnr 1-D False, real act25 1-D False, real kcha 1-D False, real koha 1-D False, real cpha 1-D False, real vcmaxha 1-D False, real jmaxha 1-D False, real tpuha 1-D False, real lmrha 1-D False, real vcmaxhd 1-D False, real jmaxhd 1-D False, real tpuhd 1-D False, real lmrse 1-D False, real qe 1-D False, real theta_cj 1-D False, real bbbopt 1-D False, real mbbopt 1-D False, real nstor 1-D False, real br_xr 1-D False, real tc_stress 0-D False, real lmrhd 1-D False,
# Variables:
# vegetation_properties_type veg_vp 0-D False
# User Types:
# DerivedType(vegetation_properties_type)
# Module Name: timeinfomod main/timeinfoMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# Variables:
# real dtime_mod 0-D True
# real dayspyr_mod 0-D False
# logical first 0-D False
# integer year_curr 0-D False
# integer year_prev 0-D False
# integer mon_curr 0-D False
# integer mon_prev 0-D False
# integer day_curr 0-D False
# integer day_prev 0-D False
# integer secs_curr 0-D False
# integer secs_prev 0-D False
# integer nstep_mod 0-D True
# integer days_per_mon 0-D False
# integer jday_mod 0-D False
# real thiscalday_mod 0-D False
# real nextsw_cday_mod 0-D False
# logical end_cd_mod 0-D False
# logical doalb 0-D False
# User Types:
# Module Name: lakecon biogeophys/LakeCon.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varctl-> integer iulog 0-D True,
# Variables:
# real tdmax 0-D True
# real emg_lake 0-D False
# real betavis 0-D True
# real z0frzlake 0-D False
# real za_lake 0-D True
# real cur0 0-D False
# real cus 0-D False
# real curm 0-D False
# real fcrit 0-D False
# real minz0lake 0-D False
# real n2min 0-D True
# real lsadz 0-D False
# real pudz 0-D True
# real depthcrit 0-D True
# real mixfact 0-D True
# logical lake_use_old_fcrit_minz0 0-D False
# real deepmixing_depthcrit 0-D False
# real deepmixing_mixfact 0-D False
# logical lake_no_ed 0-D True
# logical lakepuddling 0-D True
# real lake_puddle_thick 0-D False
# User Types:
# Module Name: qsatmod biogeophys/QSatMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use shr_const_mod-> real shr_const_tkfrz 0-D False,
# use elm_varcon-> real rwat 0-D False,
# Variables:
# real a0 0-D False
# real a1 0-D False
# real a2 0-D False
# real a3 0-D False
# real a4 0-D False
# real a5 0-D False
# real a6 0-D False
# real a7 0-D False
# real a8 0-D False
# real b0 0-D False
# real b1 0-D False
# real b2 0-D False
# real b3 0-D False
# real b4 0-D False
# real b5 0-D False
# real b6 0-D False
# real b7 0-D False
# real b8 0-D False
# real c0 0-D False
# real c1 0-D False
# real c2 0-D False
# real c3 0-D False
# real c4 0-D False
# real c5 0-D False
# real c6 0-D False
# real c7 0-D False
# real c8 0-D False
# real d0 0-D False
# real d1 0-D False
# real d2 0-D False
# real d3 0-D False
# real d4 0-D False
# real d5 0-D False
# real d6 0-D False
# real d7 0-D False
# real d8 0-D False
# User Types:
# Module Name: tridiagonalmod biogeophys/TridiagonalMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> integer iulog 0-D True,
# use decompmod-> bounds_type,
# Variables:
# User Types:
# Module Name: elm_varpar main/elm_varpar.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> logical use_extralakelayers 0-D False, logical use_vertsoilc 0-D False, logical use_crop 0-D False, logical use_betr 0-D False, logical use_century_decomp 0-D False, logical use_c13 0-D False, logical use_c14 0-D False, logical use_fates 0-D True, integer iulog 0-D True, logical create_crop_landunit 0-D False, logical irrigate 0-D False, logical use_vichydro 0-D False, logical use_extrasnowlayers 0-D False,
# Variables:
# logical more_vertlayers 0-D False
# integer nlev_equalspace 0-D False
# integer toplev_equalspace 0-D False
# integer nlevsoi 0-D True
# integer nlevsoifl 0-D False
# integer nlevgrnd 0-D True
# integer nlevurb 0-D True
# integer nlevlak 0-D True
# integer nlevdecomp 0-D False
# integer nlevdecomp_full 0-D False
# integer nlevtrc_soil 0-D False
# integer nlevtrc_full 0-D False
# integer nlevsno 0-D True
# integer ngases 0-D False
# integer nlevcan 0-D True
# integer nvegwcs 0-D False
# integer numwat 0-D False
# integer numrad 0-D True
# integer nmonth 0-D False
# integer ivis 0-D False
# integer inir 0-D False
# integer numsolar 0-D False
# integer ndst 0-D False
# integer dst_src_nbr 0-D False
# integer sz_nbr 0-D False
# integer mxpft 0-D False
# integer numveg 0-D False
# integer nlayer 0-D False
# integer nlayert 0-D False
# integer numpft 0-D False
# integer numcft 0-D False
# logical crop_prog 0-D False
# integer maxpatch_urb 0-D False
# integer mxpft_nc 0-D False
# integer maxpatch_pft 0-D False
# integer nsoilorder 0-D False
# integer nlevslp 0-D False
# integer i_met_lit 0-D False
# integer i_cel_lit 0-D False
# integer i_lig_lit 0-D False
# integer i_cwd 0-D False
# integer ndecomp_pools 0-D False
# integer ndecomp_cascade_transitions 0-D False
# integer natpft_lb 0-D False
# integer natpft_ub 0-D False
# integer natpft_size 0-D False
# integer cft_lb 0-D False
# integer cft_ub 0-D False
# integer cft_size 0-D False
# integer maxpatch_glcmec 0-D False
# integer max_patch_per_col 0-D False
# real mach_eps 0-D False
# User Types:
# Module Name: elm_varcon main/elm_varcon.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# ...
# real glcmec_rain_snow_threshold 0-D False
# integer i 0-D False
# real nitrif_n2o_loss_frac 0-D False
# real frac_minrlztn_to_no3 0-D False
# character grlnd 0-D False
# character namea 0-D False
# character nameg 0-D False
# character namet 0-D False
# character namel 0-D False
# character namec 0-D False
# character namep 0-D False
# character namecohort 0-D False
# real betads 0-D False
# real betais 0-D False
# real omegas 1-D False
# real zlak 1-D False
# real dzlak 1-D False
# real zsoi 1-D False
# real dzsoi 1-D False
# real zisoi 1-D False
# real dzsoi_decomp 1-D False
# integer nlvic 1-D False
# real dzvic 1-D False
# real zsoifl 1-D False
# real zisoifl 1-D False
# real dzsoifl 1-D False
# real catomw 0-D False
# real natomw 0-D False
# real s_con 2-D False
# real d_con_w 2-D False
# real d_con_g 2-D False
# real c_h_inv 1-D False
# real kh_theta 1-D False
# real kh_tbase 0-D False
# real snw_rds_min 0-D False
# User Types:
# Module Name: elm_varctl main/elm_varctl.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True, integer shr_kind_cl 0-D False, integer shr_kind_cs 0-D False,
# Variables:
# integer iundef 0-D False
# real rundef 0-D False
# integer fname_len 0-D False
# character caseid 0-D False
# character ctitle 0-D False
# integer nsrest 0-D False
# integer nsrstartup 0-D False
# integer nsrcontinue 0-D False
# integer nsrbranch 0-D False
# logical brnch_retain_casename 0-D False
# logical noland 0-D False
# character hostname 0-D False
# character username 0-D False
# character source 0-D False
# character version 0-D False
# character conventions 0-D False
# integer iulog 0-D True
# logical outnc_large_files 0-D False
# character finidat 0-D False
# character fsurdat 0-D False
# character fatmgrid 0-D False
# character fatmlndfrc 0-D False
# character fatmtopo 0-D False
# character flndtopo 0-D False
# character paramfile 0-D False
# character nrevsn 0-D False
# character fsnowoptics 0-D False
# character fsnowaging 0-D False
# character fsoilordercon 0-D False
# logical use_voc 0-D False
# logical bound_h2osoi 0-D False
# character finidat_interp_source 0-D False
# character finidat_interp_dest 0-D False
# logical irrigate 0-D False
# logical tw_irr 0-D False
# logical extra_gw_irr 0-D False
# logical firrig_data 0-D False
# logical create_crop_landunit 0-D False
# logical all_active 0-D False
# character co2_type 0-D False
# integer spinup_state 0-D False
# integer nyears_ad_carbon_only 0-D False
# real spinup_mortality_factor 0-D False
# logical anoxia 0-D False
# logical override_bgc_restart_mismatch_dump 0-D False
# logical carbon_only 0-D False
# logical carbonnitrogen_only 0-D False
# logical carbonphosphorus_only 0-D False
# integer subgridflag 0-D False
# logical wrtdia 0-D False
# real co2_ppmv 0-D False
# logical const_climate_hist 0-D False
# logical use_c13 0-D False
# logical use_c14 0-D False
# logical use_fates 0-D True
# integer fates_spitfire_mode 0-D False
# logical use_fates_fixed_biogeog 0-D False
# logical use_fates_logging 0-D False
# logical use_fates_planthydro 0-D False
# logical use_fates_cohort_age_tracking 0-D False
# logical use_fates_ed_st3 0-D False
# logical use_fates_ed_prescribed_phys 0-D False
# logical use_fates_inventory_init 0-D False
# logical use_fates_nocomp 0-D False
# logical use_fates_sp 0-D False
# character fates_inventory_ctrl_filename 0-D False
# integer fates_parteh_mode 0-D False
# logical use_betr 0-D False
# logical use_lai_streams 0-D False
# logical use_hydrstress 0-D False
# logical use_dynroot 0-D False
# logical create_glacier_mec_landunit 0-D False
# logical glc_smb 0-D False
# logical glc_do_dynglacier 0-D False
# logical glcmec_downscale_rain_snow_convert 0-D False
# logical glcmec_downscale_longwave 0-D False
# integer glc_snow_persistence_max_days 0-D False
# character glc_grid 0-D False
# character fglcmask 0-D False
# logical single_column 0-D False
# real scmlat 0-D False
# real scmlon 0-D False
# integer inst_index 0-D False
# character inst_name 0-D False
# character inst_suffix 0-D False
# integer nsegspc 0-D False
# character rpntdir 0-D False
# character rpntfil 0-D False
# logical hist_wrtch4diag 0-D False
# character fates_paramfile 0-D False
# logical use_nofire 0-D False
# logical use_lch4 0-D True
# logical use_vertsoilc 0-D False
# logical use_extralakelayers 0-D False
# logical use_vichydro 0-D False
# logical use_century_decomp 0-D False
# logical use_cn 0-D False
# logical use_cndv 0-D False
# logical use_crop 0-D False
# logical use_snicar_frc 0-D True
# logical use_snicar_ad 0-D False
# logical use_extrasnowlayers 0-D False
# logical use_vancouver 0-D False
# logical use_mexicocity 0-D False
# logical use_noio 0-D False
# logical use_var_soil_thick 0-D False
# logical use_atm_downscaling_to_topunit 0-D False
# character precip_downscaling_method 0-D False
# logical use_lake_wat_storage 0-D False
# logical use_vsfm 0-D False
# logical vsfm_use_dynamic_linesearch 0-D False
# logical vsfm_include_seepage_bc 0-D False
# character vsfm_satfunc_type 0-D False
# character vsfm_lateral_model_type 0-D False
# logical use_petsc_thermal_model 0-D False
# logical use_em_stub 0-D False
# character nlfilename_in 0-D False
# logical elmvarctl_isset 0-D False
# character nu_com 0-D False
# logical forest_fert_exp 0-D False
# logical eca_pconst_rgspin 0-D False
# logical nfix_ptase_plant 0-D False
# character startdate_add_temperature 0-D False
# character startdate_add_co2 0-D False
# real add_co2 0-D False
# real add_temperature 0-D False
# logical lateral_connectivity 0-D False
# character domain_decomp_type 0-D False
# logical use_pheno_flux_limiter 0-D False
# logical use_erosion 0-D False
# logical ero_ccycle 0-D False
# logical use_elm_interface 0-D False
# logical use_elm_bgc 0-D False
# logical use_pflotran 0-D False
# logical pf_surfaceflow 0-D False
# logical pf_cmode 0-D False
# logical pf_hmode 0-D False
# logical pf_tmode 0-D False
# logical pf_frzmode 0-D False
# logical initth_pf2clm 0-D False
# integer pf_elmnstep0 0-D False
# character metdata_type 0-D False
# character metdata_bypass 0-D False
# character metdata_biases 0-D False
# character co2_file 0-D False
# character aero_file 0-D False
# logical do_budgets 0-D False
# integer budget_inst 0-D False
# integer budget_daily 0-D False
# integer budget_month 0-D False
# integer budget_ann 0-D False
# integer budget_ltann 0-D False
# integer budget_ltend 0-D False
# User Types:
# Module Name: subgridmod main/subgridMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varctl-> iulog, create_crop_landunit,
# use elm_varpar-> natpft_size, cft_size, maxpatch_urb, maxpatch_glcmec,
# use elm_varsur-> wt_lunit, urban_valid, wt_glc_mec,
# use landunit_varcon-> istsoil, istcrop, istice, istice_mec, istdlak, istwet, isturb_tbd, isturb_hd, isturb_md,
# use topounit_varcon-> max_topounits, has_topounit,
# Variables:
# User Types:
# Module Name: filtermod main/filterMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use elm_varctl-> iulog,
# use decompmod-> bounds_type, get_proc_clumps, get_clump_bounds, bounds_level_clump,
# use gridcelltype-> grc_pp,
# use landunittype-> lun_pp,
# use columntype-> col_pp,
# use vegetationtype-> veg_pp,
# use topounittype-> top_pp,
# use pftvarcon-> npcropmin, nppercropmin,
# use landunit_varcon-> istsoil, istcrop, istice_mec,
# use column_varcon-> icol_road_perv,
# Variables:
# clumpfilter filter 1-D False
# clumpfilter filter_inactive_and_active 1-D False
# User Types:
# DerivedType(clumpfilter)
# Module Name: soiltemperaturemod biogeophys/SoilTemperatureMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varctl-> iulog, use_petsc_thermal_model,
# use elm_varcon-> spval, cnfac, cpice, cpliq, denh2o, denice, tfrz, tkwat, tkice, tkair, thk_bedrock, hfus, grav, sb, hvap, capr,
# use urbanparamstype-> urbanparams_type,
# use atm2lndtype-> atm2lnd_type,
# use canopystatetype-> canopystate_type,
# use solarabsorbedtype-> solarabs_type,
# use soilstatetype-> soilstate_type,
# use energyfluxtype-> energyflux_type,
# use topounitdatatype-> top_af,
# use landunittype-> lun_pp,
# use landunitdatatype-> lun_es, lun_ef,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ef, col_ws, col_wf,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_ef, veg_wf,
# use timeinfomod-> all
# use perfmod_gpu-> all
# use elm_varpar-> nlevsno, nlevgrnd, nlevurb, nlevsoi, max_patch_per_col,
# use landunit_varcon-> istice, istice_mec, istsoil, istcrop, istwet,
# use column_varcon-> icol_roof, icol_sunwall, icol_shadewall, icol_road_perv, icol_road_imperv,
# use banddiagonalmod-> banddiagonal,
# Variables:
# integer default_thermal_model 0-D False
# integer petsc_thermal_model 0-D False
# integer thermal_model 0-D False
# real thin_sfclayer 0-D False
# User Types:
# Module Name: landunitdatatype data_types/LandunitDataType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevlak 0-D True, integer nlevurb 0-D True,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# use elm_varctl-> logical use_vancouver 0-D False, logical use_mexicocity 0-D False,
# use decompmod-> bounds_type,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# Variables:
# landunit_energy_state lun_es 0-D False
# landunit_energy_flux lun_ef 0-D False
# landunit_water_state lun_ws 0-D False
# User Types:
# DerivedType(landunit_energy_state)
# DerivedType(landunit_energy_flux)
# DerivedType(landunit_water_state)
# Module Name: perfmod_gpu main/perfMod_GPU.F90
# Module Depedencies:
# Variables:
# User Types:
# Module Name: banddiagonalmod biogeophys/BandDiagonalMod.F90
# Module Depedencies:
# use decompmod-> bounds_type,
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> integer iulog 0-D True,
# Variables:
# User Types:
# Module Name: surfacealbedomod biogeophys/SurfaceAlbedoMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use landunit_varcon-> istsoil, istcrop, istdlak, istice, istice_mec,
# use elm_varcon-> grlnd, namep, namet, tfrz, omegas, betads, betais,
# use elm_varpar-> numrad, nlevcan, nlevsno,
# use elm_varctl-> fsurdat, iulog, subgridflag, use_snicar_frc, use_fates, use_snicar_ad,
# use vegetationpropertiestype-> veg_vp,
# use snowsnicarmod-> sno_nbr_aer, snicar_rt, snicar_ad_rt, do_sno_aer, do_sno_oc,
# use aerosoltype-> aerosol_type,
# use canopystatetype-> canopystate_type,
# use lakestatetype-> lakestate_type,
# use surfacealbedotype-> surfalb_type, lake_melt_icealb, alblak, alblakwi, albice, albsat, albdry, isoicol,
# use gridcelltype-> grc_pp,
# use landunittype-> lun_pp,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ws,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_es, veg_ws,
# use topounit_varcon-> max_topounits,
# use topounittype-> top_pp,
# use shr_orb_mod-> all
# use lakecon-> lakepuddling,
# use domainmod-> ldomain,
# Variables:
# real calb 0-D False
# User Types:
# Module Name: snowsnicarmod biogeophys/SnowSnicarMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varctl-> integer iulog 0-D True, logical use_extrasnowlayers 0-D False, character fsnowoptics 0-D False, character fsnowaging 0-D False,
# use elm_varcon-> character namec 0-D False, real spval 0-D True,
# use shr_const_mod-> real shr_const_rhoice 0-D False, real shr_const_pi 0-D True,
# use decompmod-> bounds_type,
# use aerosolmod-> real snw_rds_min 0-D True,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# use landunittype-> landunit_physical_properties lun_pp 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use columndatatype-> column_energy_state col_es 0-D False, column_water_state col_ws 0-D False, column_water_flux col_wf 0-D False,
# use timeinfomod-> all
# use elm_varpar-> integer nlevsno 0-D True, integer numrad 0-D True,
# Variables:
# integer sno_nbr_aer 0-D False
# logical do_sno_oc 0-D False
# logical do_sno_aer 0-D False
# integer numrad_snw 0-D False
# integer nir_bnd_bgn 0-D False
# integer nir_bnd_end 0-D False
# integer idx_mie_snw_mx 0-D False
# integer idx_t_max 0-D False
# integer idx_t_min 0-D False
# integer idx_tgrd_max 0-D False
# integer idx_tgrd_min 0-D False
# integer idx_rhos_max 0-D False
# integer idx_rhos_min 0-D False
# integer idx_bc_nclrds_min 0-D False
# integer idx_bc_nclrds_max 0-D False
# integer idx_bcint_icerds_min 0-D False
# integer idx_bcint_icerds_max 0-D False
# integer snw_rds_max_tbl 0-D False
# integer snw_rds_min_tbl 0-D False
# real snw_rds_max 0-D False
# real snw_rds_refrz 0-D False
# real min_snw 0-D False
# real c1_liq_brun89 0-D False
# real c2_liq_brun89 0-D False
# real tim_cns_bc_rmv 0-D False
# real tim_cns_oc_rmv 0-D False
# real tim_cns_dst_rmv 0-D False
# logical flg_snoage_scl 0-D False
# real xdrdt 0-D False
# real ss_alb_snw_drc     ; 2-D False
# real asm_prm_snw_drc    ; 2-D False
# real ext_cff_mss_snw_drc; 2-D False
# real ss_alb_snw_dfs     ; 2-D False
# real asm_prm_snw_dfs    ; 2-D False
# real ext_cff_mss_snw_dfs; 2-D False
# real ss_alb_bc1     ; 2-D False
# real asm_prm_bc1    ; 2-D False
# real ext_cff_mss_bc1; 2-D False
# real ss_alb_bc2     ; 2-D False
# real asm_prm_bc2    ; 2-D False
# real ext_cff_mss_bc2; 2-D False
# real ss_alb_bc1     ; 1-D False
# real asm_prm_bc1    ; 1-D False
# real ext_cff_mss_bc1; 1-D False
# real ss_alb_bc2     ; 1-D False
# real asm_prm_bc2    ; 1-D False
# real ext_cff_mss_bc2; 1-D False
# real ss_alb_oc1     ; 1-D False
# real asm_prm_oc1    ; 1-D False
# real ext_cff_mss_oc1; 1-D False
# real ss_alb_oc2     ; 1-D False
# real asm_prm_oc2    ; 1-D False
# real ext_cff_mss_oc2; 1-D False
# real ss_alb_dst1     ; 1-D False
# real asm_prm_dst1    ; 1-D False
# real ext_cff_mss_dst1; 1-D False
# real ss_alb_dst2     ; 1-D False
# real asm_prm_dst2    ; 1-D False
# real ext_cff_mss_dst2; 1-D False
# real ss_alb_dst3     ; 1-D False
# real asm_prm_dst3    ; 1-D False
# real ext_cff_mss_dst3; 1-D False
# real ss_alb_dst4     ; 1-D False
# real asm_prm_dst4    ; 1-D False
# real ext_cff_mss_dst4; 1-D False
# real bcenh; 3-D False
# real snowage_tau 3-D False
# real snowage_kappa 3-D False
# real snowage_drdt0 3-D False
# User Types:
# Module Name: aerosolmod biogeophys/AerosolMod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varpar-> integer nlevsno 0-D True,
# use elm_varctl-> logical use_extrasnowlayers 0-D False,
# use atm2lndtype-> atm2lnd_type,
# use aerosoltype-> aerosol_type,
# use columntype-> column_physical_properties col_pp 0-D False,
# use columndatatype-> column_water_state col_ws 0-D False, column_water_flux col_wf 0-D False,
# use timeinfomod-> all
# Variables:
# real snw_rds_min 0-D True
# User Types:
# Module Name: aerosoltype biogeophys/AerosolType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use elm_varpar-> integer nlevsno 0-D True, integer nlevgrnd 0-D True, integer nlevsoi 0-D True,
# use decompmod-> bounds_type,
# use elm_varcon-> real spval 0-D True, integer ispval 0-D False,
# use elm_varctl-> integer iulog 0-D True,
# Variables:
# User Types:
# DerivedType(aerosol_type)
# Module Name: surfacealbedotype biogeophys/SurfaceAlbedoType.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True,
# use decompmod-> bounds_type,
# use elm_varpar-> integer numrad 0-D True, integer nlevcan 0-D True, integer nlevsno 0-D True,
# use elm_varctl-> character fsurdat 0-D False, integer iulog 0-D True, logical use_snicar_frc 0-D True,
# use elm_varcon-> character grlnd 0-D False, real spval 0-D True, integer ispval 0-D False,
# use columntype-> column_physical_properties col_pp 0-D False,
# use topounit_varcon-> integer max_topounits 0-D False,
# use gridcelltype-> gridcell_physical_properties_type grc_pp 0-D False,
# Variables:
# real albice 1-D False
# real lake_melt_icealb 1-D False
# real alblak 1-D False
# real alblakwi 1-D False
# real albsat 2-D False
# real albdry 2-D False
# integer isoicol 1-D False
# User Types:
# DerivedType(surfalb_type)
# Module Name: shr_orb_mod util/shr_orb_mod.F90
# Module Depedencies:
# use shr_kind_mod-> integer shr_kind_r8 0-D True, integer shr_kind_in 0-D False,
# use shr_const_mod-> all
# Variables:
# real shr_orb_undef_real 0-D False
# integer shr_orb_undef_int 0-D False
# real pi 0-D False
# real shr_orb_eccen_min 0-D False
# real shr_orb_eccen_max 0-D False
# real shr_orb_obliq_min 0-D False
# real shr_orb_obliq_max 0-D False
# real shr_orb_mvelp_min 0-D False
# real shr_orb_mvelp_max 0-D False
# real constant_zenith_angle_deg 0-D False
# User Types:

# %%
sub_dict["laketemperature"].print_subroutine_info()

# %%
print(len(mod_dict))

# %%
eo.create_dataframe(sub_dict)

# %%
import mariadb
import sys
try:
    conn = mariadb.connect(
        user="root",
        password="root",
        host="127.0.0.1",
        port=3306,
        database="spel",
        # unix_socket='/var/run/mysqld/mysqld.sock'  # Use the correct path
    )
except mariadb.Error as e:
    print("error")
    sys.exit(1)
cur = conn.cursor()

# %%
import csv
with open("test.csv", "r", ) as file:
    reader = csv.reader(file)
    f = 0
    for i in reader:
        if f == 0: 
            f += 1
            continue
        cur.execute(
            "INSERT INTO mods (`subroutine`, `variable_name`, `status`) VALUES (%s, %s, %s)",
            (i[1].strip(), i[2].strip(), i[3].strip())
        )

# %%
# cur = conn.cursor()
# t = "test"
# p = "p"
# cur.execute(
#     "INSERT INTO mods (`subroutine`, `var_name`) VALUES (%s, %s)",
#     (t, p)
# )
conn.commit()

# %%
def query(table, id="%", subroutine="%", var_name="%"):
    statement = f"select * from {table} "
    statement += f"where id like '{id}'" if id=="%" else f"where id='{id}'"
    statement += " and "
    statement += f"subroutine like '{subroutine}'" if subroutine=="%" else f"subroutine='{subroutine}'"
    statement += " and "
    statement += f"variable_name like '{var_name}'" if var_name=="%" else f"variable_name='{var_name}'"
    print(statement)
    cur.execute(
        # f"select * from {table} where id='{id}' and subroutine='{subroutine}' and variable_name='{var_name}'"
        statement
    )
    conn.commit()
    print(list(cur))

# %%
# cur.execute(
#     # "select * from subroutine_active_global_vars where id='1' and subroutine like '%' and variable_name='"
#     "select * from subroutine_active_global_vars where id like '%' and subroutine like '%' and variable_name='bounds%endc'"
# )
# conn.commit()
# print(list(cur))
query("subroutine_active_global_vars", var_name="bounds%endc")
