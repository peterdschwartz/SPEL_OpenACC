# %% [markdown]
# # Demo for SPEL

# %%
# %tb
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Built-in modules
import re        # Regular expressions
import importlib # MUST BE USED TO RELOAD MODULES
import sys 

# Importing modules for SPEL functions 
import utilityFunctions as uf
import edit_files as ef 
import fortran_modules as fm 
from analyze_subroutines import Subroutine

# mod_config : system configuration and static variables. 
# Where E3SM is stored, where unit tests are stored, etc.
from mod_config import default_mods, unittests_dir, scripts_dir, spel_mods_dir
from mod_config import ELM_SRC, spel_output_dir, _bc
# Out:
# No traceback available to show.

# %% [markdown]
# SPEL needs a "casename" (what your unit-test is called) and a list of subroutines to create a unit-test for "sub_name_list" (examples are "LakeTemperature", "SoilTemperature", etc...)

# %%
# Define Unit Test parameters 
import os 
casename = "notebook_test"  # Name of the test case
case_dir = unittests_dir + casename # Directory to store the test case

# create directory for unit-test if it does not exist
if(not os.path.isdir(f"{case_dir}") ):
    print(f"Making case directory {case_dir}")
    if(not os.path.isdir(f"{unittests_dir}")):
        os.system(f"mkdir {unittests_dir}")
    os.system(f"mkdir {case_dir}")
    preprocess = True

# List of subroutines to be analyzed
sub_name_list = ["SoilTemperature","LakeTemperature"] 
sub_name_list = [sub.lower() for sub in sub_name_list]

# variables needed for Unit Test
main_sub_dict = {}  # Dictionary to store all Subroutines in files needed for Unit Test
mod_dict = {} 
subroutines = {k.lower():[] for k in sub_name_list} # Dictionary for User Specified Subroutines

# %% [markdown]
# 1st step for SPEL is determine which modules are needed for LakeTemperature and edit out the I/O, MPI, and other unneccessary modules. This must be somewhat tailored to ELM.
#
# Currently if I module is not present in the "components/elm/src/" (ELM_SRC) nor in the "share/utils" directories (SHR_SRC), then the module and any dependency on it is automatically removed.

# %%
 # List to hold all the modules needed for the unit test
needed_mods = [] 
for s in sub_name_list:
    # Get general info of the subroutine
    subroutines[s] = Subroutine(s,calltree=['elm_drv'])

    # Process by removing certain modules and syntax
    # so that a standalone unit test can be compiled.
    fn = subroutines[s].filepath
    mod_dict, file_list, main_sub_dict = ef.process_for_unit_test(
                fname=fn,
                case_dir=case_dir,
                mod_dict=mod_dict,
                mods=needed_mods,
                required_mods=default_mods,
                main_sub_dict=main_sub_dict,
                overwrite=True,
                verbose=False,
            )

    subroutines[s] = main_sub_dict[s]
# Out:
# Adding clumps to clump_type instances
# Adding filter to clumpfilter instances
# Adding filter_inactive_and_active to clumpfilter instances
# dict_keys(['soiltemperaturemod', 'shr_kind_mod', 'decompmod', 'domainmod', 'elm_varctl', 'elm_varcon', 'shr_const_mod', 'urbanparamstype', 'gridcelltype', 'topounit_varcon', 'elm_varsur', 'atm2lndtype', 'canopystatetype', 'solarabsorbedtype', 'soilstatetype', 'ch4varcon', 'pftvarcon', 'sharedparamsmod', 'funcpedotransfermod', 'rootbiophysmod', 'domainlateralmod', 'energyfluxtype', 'annualfluxdribbler', 'topounitdatatype', 'topounittype', 'landunittype', 'landunitdatatype', 'columntype', 'columndatatype', 'soilorder_varcon', 'cnstatetype', 'cndecompcascadecontype', 'vegetationtype', 'vegetationdatatype', 'subgridavemod', 'speciesmod', 'vegetationpropertiestype', 'dynsubgridcontrolmod', 'timeinfomod', 'perfmod_gpu', 'elm_varpar', 'landunit_varcon', 'column_varcon', 'banddiagonalmod', 'subgridmod', 'filtermod'])
# dict_keys(['soiltemperaturemod', 'shr_kind_mod', 'decompmod', 'domainmod', 'elm_varctl', 'elm_varcon', 'shr_const_mod', 'urbanparamstype', 'gridcelltype', 'topounit_varcon', 'elm_varsur', 'atm2lndtype', 'canopystatetype', 'solarabsorbedtype', 'soilstatetype', 'ch4varcon', 'pftvarcon', 'sharedparamsmod', 'funcpedotransfermod', 'rootbiophysmod', 'domainlateralmod', 'energyfluxtype', 'annualfluxdribbler', 'topounitdatatype', 'topounittype', 'landunittype', 'landunitdatatype', 'columntype', 'columndatatype', 'soilorder_varcon', 'cnstatetype', 'cndecompcascadecontype', 'vegetationtype', 'vegetationdatatype', 'subgridavemod', 'speciesmod', 'vegetationpropertiestype', 'dynsubgridcontrolmod', 'timeinfomod', 'perfmod_gpu', 'elm_varpar', 'landunit_varcon', 'column_varcon', 'banddiagonalmod', 'subgridmod', 'filtermod', 'laketemperaturemod', 'ch4mod', 'lnd2atmtype', 'soilhydrologytype', 'shr_spfn_mod', 'lakestatetype', 'lakecon', 'qsatmod', 'tridiagonalmod'])

# %%
# Create dictionary containing all identified user defined types
# 'type-name' : 'DerivedType Object'
type_dict = {}
for modname, mod in mod_dict.items():
    for utype, dtype in mod.defined_types.items():
        type_dict[utype] = dtype

# %% [markdown]
# SPEL can print out a module tree showing how the modules are linked for the unit-test subroutines
# - The full tree can be pretty difficult to parse, having a cutoff depth is recommended.
# - Every module uses 'shr_kind_mod' so that could be suppressed as well.

# %%
modtree = fm.print_spel_module_dependencies(mod_dict=mod_dict,subs=subroutines)

# Print the module tree
arrow = "-->"
cutoff_depth = 10 # Only print modules up to this depth
suppress_mod_list = ['shr_kind_mod']
for m in modtree:
    depth = m['depth']
    modname = m['module']
    if(modname in suppress_mod_list):
        continue
    if(depth == 1):
        print(_bc.HEADER + arrow*depth + modname + _bc.ENDC)
    elif(depth <= cutoff_depth):
        print( arrow*depth + modname)
# Out:
# soiltemperaturemod
# -->decompmod
# -->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->domainmod
# -->-->-->elm_varctl
# -->elm_varctl
# -->elm_varcon
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->urbanparamstype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->topounit_varcon
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->domainmod
# -->-->-->elm_varctl
# -->-->elm_varsur
# -->atm2lndtype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->canopystatetype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->solarabsorbedtype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->landunit_varcon
# -->soilstatetype
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->topounit_varcon
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->sharedparamsmod
# -->-->funcpedotransfermod
# -->-->rootbiophysmod
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->domainlateralmod
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->energyfluxtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->annualfluxdribbler
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->shr_const_mod
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->topounitdatatype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->topounittype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->landunittype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->landunitdatatype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->columntype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->columndatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->soilorder_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->cndecompcascadecontype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->timeinfomod
# -->-->urbanparamstype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->-->elm_varsur
# -->vegetationtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->vegetationdatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->subgridavemod
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->topounittype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->speciesmod
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->vegetationpropertiestype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->columndatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->soilorder_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->cndecompcascadecontype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->timeinfomod
# -->-->-->urbanparamstype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varsur
# -->-->timeinfomod
# -->-->dynsubgridcontrolmod
# -->-->-->elm_varctl
# -->timeinfomod
# -->perfmod_gpu
# -->elm_varpar
# -->-->elm_varctl
# -->landunit_varcon
# -->column_varcon
# -->-->landunit_varcon
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->banddiagonalmod
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# laketemperaturemod
# -->decompmod
# -->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->domainmod
# -->-->-->elm_varctl
# -->ch4mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->sharedparamsmod
# -->-->atm2lndtype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->canopystatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->energyfluxtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->annualfluxdribbler
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->shr_const_mod
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->lakestatetype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->lnd2atmtype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->soilhydrologytype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->sharedparamsmod
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->shr_const_mod
# -->-->-->shr_spfn_mod
# -->-->-->-->shr_const_mod
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->soilstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->sharedparamsmod
# -->-->-->funcpedotransfermod
# -->-->-->rootbiophysmod
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->domainlateralmod
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->topounitdatatype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->topounittype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->columndatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->soilorder_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->cndecompcascadecontype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->timeinfomod
# -->-->-->urbanparamstype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varsur
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->vegetationdatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->subgridavemod
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->topounittype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->decompmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->speciesmod
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->vegetationpropertiestype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->columndatatype
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->ch4varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->pftvarcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# ...
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->landunit_varcon
# -->columntype
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->columndatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->-->ch4varcon
# -->-->-->elm_varctl
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->soilorder_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->column_varcon
# -->-->-->landunit_varcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->cndecompcascadecontype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->columntype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->timeinfomod
# -->-->urbanparamstype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->-->elm_varsur
# -->vegetationtype
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->vegetationdatatype
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->landunit_varcon
# -->-->pftvarcon
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->subgridavemod
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->topounittype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->cnstatetype
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->vegetationtype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->gridcelltype
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->speciesmod
# -->-->vegetationtype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->vegetationpropertiestype
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->landunittype
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->gridcelltype
# -->-->-->landunit_varcon
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->topounit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->columndatatype
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->-->-->ch4varcon
# -->-->-->-->elm_varctl
# -->-->-->pftvarcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->soilorder_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->landunit_varcon
# -->-->-->column_varcon
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->decompmod
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->cnstatetype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->columntype
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->vegetationtype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->cndecompcascadecontype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->columntype
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->landunittype
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->timeinfomod
# -->-->-->urbanparamstype
# -->-->-->-->decompmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->-->elm_varcon
# -->-->-->-->-->shr_const_mod
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varctl
# -->-->-->-->landunittype
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->gridcelltype
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->topounit_varcon
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varcon
# -->-->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->domainmod
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->topounit_varcon
# -->-->-->-->-->elm_varctl
# -->-->-->-->-->elm_varcon
# -->-->-->-->-->-->shr_const_mod
# -->-->-->-->-->-->elm_varpar
# -->-->-->-->-->-->-->elm_varctl
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->-->domainmod
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->column_varcon
# -->-->-->-->-->landunit_varcon
# -->-->-->-->-->elm_varpar
# -->-->-->-->-->-->elm_varctl
# -->-->-->-->landunit_varcon
# -->-->-->-->domainmod
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varsur
# -->-->timeinfomod
# -->-->dynsubgridcontrolmod
# -->-->-->elm_varctl
# -->timeinfomod
# -->lakecon
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->-->elm_varctl
# -->qsatmod
# -->-->shr_const_mod
# -->-->elm_varcon
# -->-->-->shr_const_mod
# -->-->-->elm_varpar
# -->-->-->-->elm_varctl
# -->-->-->elm_varctl
# -->tridiagonalmod
# -->-->elm_varctl
# -->-->decompmod
# -->-->-->elm_varctl
# -->-->-->elm_varcon
# -->-->-->-->shr_const_mod
# -->-->-->-->elm_varpar
# -->-->-->-->-->elm_varctl
# -->-->-->-->elm_varctl
# -->-->-->domainmod
# -->-->-->-->elm_varctl
# -->elm_varpar
# -->-->elm_varctl
# -->elm_varcon
# -->-->shr_const_mod
# -->-->elm_varpar
# -->-->-->elm_varctl
# -->-->elm_varctl
# -->elm_varctl

# %%
test_mod = mod_dict['soiltemperaturemod']
test_mod.print_module_info()
# Out:
# Module Name: soiltemperaturemod biogeophys/SoilTemperatureMod.F90
# Module Depedencies:
# use shr_kind_mod-> shr_kind_r8,
# use decompmod-> bounds_type,
# use elm_varctl-> iulog, use_petsc_thermal_model,
# use elm_varcon-> spval, cnfac, cpice, cpliq, denh2o, denice, tfrz, tkwat, tkice, tkair, thk_bedrock, hfus, grav, sb, hvap, capr,
# use urbanparamstype-> urbanparams_type,
# use atm2lndtype-> atm2lnd_type,
# use canopystatetype-> canopystate_type,
# use solarabsorbedtype-> solarabs_type,
# use soilstatetype-> soilstate_type,
# use energyfluxtype-> energyflux_type,
# use topounitdatatype-> top_af,
# use landunittype-> lun_pp,
# use landunitdatatype-> lun_es, lun_ef,
# use columntype-> col_pp,
# use columndatatype-> col_es, col_ef, col_ws, col_wf,
# use vegetationtype-> veg_pp,
# use vegetationdatatype-> veg_ef, veg_wf,
# use timeinfomod-> all
# use perfmod_gpu-> all
# use elm_varpar-> nlevsno, nlevgrnd, nlevurb, nlevsoi, max_patch_per_col,
# use landunit_varcon-> istice, istice_mec, istsoil, istcrop, istwet,
# use column_varcon-> icol_roof, icol_sunwall, icol_shadewall, icol_road_perv, icol_road_imperv,
# use banddiagonalmod-> banddiagonal,
# Variables:
# integer default_thermal_model 0-D False
# integer petsc_thermal_model 0-D False
# integer thermal_model 0-D False
# real thin_sfclayer 0-D False
# User Types:

# %%
for s in sub_name_list:
    # Parsing means getting info on the variables read and written
    # to by the subroutine and any of its callees
    subroutines[s].parse_subroutine(dtype_dict=type_dict,
                                    main_sub_dict=main_sub_dict,verbose=True)
# Out:
# parse_args:: Inactive args in setrhsvec_snowurbannonroad
# ['bounds', 'hs_top_snow']
# parse_args:: Inactive args in setrhsvec_snowurbanroad
# ['bounds', 'hs_top', 't_h2osfc']
# parse_args:: Inactive args in setrhsvec_snowurban
# ['bounds', 't_h2osfc']
# parse_args:: Inactive args in setrhsvec_snownonurban
# ['bounds', 'hs_top']
# parse_args:: Inactive args in setrhsvec_snow
# ['bounds']
# parse_args::::Adjusted Argumnet line number for setrhsvec_standingsurfacewater in CPP file
# parse_args:: Inactive args in setrhsvec_soilurbannonroad
# ['bounds', 'hs_top_snow', 'hs_soil', 'fn_h2osfc', 'c_h2osfc']
# parse_args:: Inactive args in setrhsvec_soilurbanroad
# ['bounds', 'hs_top', 'fn_h2osfc', 'c_h2osfc']
# parse_args:: Inactive args in setrhsvec_soilurban
# ['bounds', 'fn_h2osfc', 'c_h2osfc']
# parse_args:: Inactive args in setrhsvec_soilnonurban
# ['bounds', 'hs_top', 'fn_h2osfc', 'c_h2osfc']
# parse_args::::Adjusted Argumnet line number for setrhsvec_soil_standingsurfacewater in CPP file
# parse_args:: Inactive args in setrhsvec_soil_standingsurfacewater
# ['bounds', 'hs_top_snow', 'hs_top', 'sabg_lyr_col', 'fn', 'c_h2osfc']
# parse_args:: Inactive args in setrhsvec_soil
# ['bounds', 'c_h2osfc']
# parse_args:: Inactive args in setrhsvec
# ['tk']
# parse_args:: Inactive args in setmatrix_snowurbannonroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snowurbanroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snowurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snownonurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow_soilurbannonroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow_soilurbanroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow_soilurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow_soilnonurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_snow_soil
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soilurbannonroad
# ['bounds', 'nband', 'tk_h2osfc', 'dz_h2osfc']
# parse_args:: Inactive args in setmatrix_soilurbanroad
# ['bounds', 'nband', 'tk_h2osfc', 'dz_h2osfc']
# parse_args:: Inactive args in setmatrix_soilurban
# ['bounds', 'nband', 'tk_h2osfc', 'dz_h2osfc']
# parse_args:: Inactive args in setmatrix_soilnonurban
# ['bounds', 'nband', 'tk_h2osfc', 'dz_h2osfc']
# parse_args:: Inactive args in setmatrix_soil
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soil_snowurbannonroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soil_snowurbanroad
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soil_snowurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soil_snownonurban
# ['bounds', 'nband']
# parse_args:: Inactive args in setmatrix_soil_snow
# ['bounds', 'nband']
# parse_args::::Adjusted Argumnet line number for setmatrix_standingsurfacewater in CPP file
# parse_args:: Inactive args in setmatrix_standingsurfacewater
# ['nband', 'tk', 'fact']
# parse_args::::Adjusted Argumnet line number for setmatrix_standingsurfacewater_soil in CPP file
# parse_args:: Inactive args in setmatrix_standingsurfacewater_soil
# ['nband', 'tk', 'fact']
# parse_args::::Adjusted Argumnet line number for setmatrix_soil_standingsurfacewater in CPP file
# parse_args:: Inactive args in setmatrix_soil_standingsurfacewater
# ['nband']
# parse_args::::Adjusted Argumnet line number for assemblematrixfromsubmatrices in CPP file
# parse_args:: Inactive args in assemblematrixfromsubmatrices
# ['nband']
# parse_args:: Inactive args in banddiagonal
# ['bounds']
# Resolving interface for tridiagonal
#  with args: ['bounds', '-nlevsno + 1', 'nlevlak + nlevgrnd', 'jtop', 'num_lakec', 'filter_lakec', 'a', 'b', 'c1', 'r', 'tx']
# /home/mrgex/SPEL_Openacc/scripts/../../repo/E3SM/components/elm/src/biogeophys/TridiagonalMod.F90 14   interface Tridiagonal
# Couldn't match -nlevsno + 1 to any known variable -- assuming xx type
# Couldn't match nlevlak + nlevgrnd to any known variable -- assuming xx type
# tridiagonal_sr:: 1 Optional arguments found
# bounds matches bounds
# -nlevsno + 1 matches lbj
# nlevlak + nlevgrnd matches ubj
# jtop matches jtop
# num_lakec matches numf
# filter_lakec matches filter
# a matches a
# b matches b
# c1 matches c
# r matches r
# tx matches u
# resolve_interface::Subroutine is tridiagonal_sr
# _preprocess_file::New child sub name is: tridiagonal_sr
# Resolving interface for tridiagonal
#  with args: ['bounds', '-nlevsno + 1', 'nlevlak + nlevgrnd', 'jtop', 'num_lakec', 'filter_lakec', 'a', 'b', 'c1', 'r', 'tx']
# /home/mrgex/SPEL_Openacc/scripts/../../repo/E3SM/components/elm/src/biogeophys/TridiagonalMod.F90 14   interface Tridiagonal
# Couldn't match -nlevsno + 1 to any known variable -- assuming xx type
# Couldn't match nlevlak + nlevgrnd to any known variable -- assuming xx type
# tridiagonal_sr:: 1 Optional arguments found
# bounds matches bounds
# -nlevsno + 1 matches lbj
# nlevlak + nlevgrnd matches ubj
# jtop matches jtop
# num_lakec matches numf
# filter_lakec matches filter
# a matches a
# b matches b
# c1 matches c
# r matches r
# tx matches u
# resolve_interface::Subroutine is tridiagonal_sr

# %%
read_types  = [] 
write_types = []
func_name = "Notebook"
for s in sub_name_list:
    subroutines[s].child_subroutines_analysis(dtype_dict=type_dict,
                                        main_sub_dict=main_sub_dict,verbose=False)

    print(_bc.OKGREEN + f"Derived Type Analysis for {subroutines[s].name}")
    print(f"{func_name}::Read-Only")
    for key in subroutines[s].elmtype_r.keys():
        print(key, subroutines[s].elmtype_r[key])
    print(f"{func_name}::Write-Only")
    for key in subroutines[s].elmtype_w.keys():
        print(key, subroutines[s].elmtype_w[key])
    print(f"{func_name}::Read-Write")
    for key in subroutines[s].elmtype_rw.keys():
        print(key, subroutines[s].elmtype_rw[key])
    print(_bc.ENDC)

    for key in list(subroutines[s].elmtype_r.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_r[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        read_types.append(key)

    for key in list(subroutines[s].elmtype_w.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_w[key]
            continue
        if "_inst" in key:
            print(f"error: {key} has _inst")
            sys.exit(1)
        write_types.append(key)

    for key in list(subroutines[s].elmtype_rw.keys()):
        c13c14 = bool("c13" in key or "c14" in key)
        if c13c14:
            del subroutines[s].elmtype_rw[key]
            continue
        write_types.append(key)
# Out:
# Warning: dgbsv not in main_sub_dict.
# Could be library function?
# Creating Subroutine dgbsv in lib.F90 L-999--999
# child_subroutines_analysis::dgbsv is a library function -- Skipping.
# Derived Type Analysis for soiltemperature
# Notebook::Read-Only
# lun_pp%urbpoi r
# urbanparams_vars%t_building_max r
# urbanparams_vars%t_building_min r
# col_pp%snl r
# col_pp%itype r
# col_pp%landunit r
# bounds%begl r
# bounds%endl r
# bounds%begc r
# bounds%endc r
# col_pp%z r
# col_pp%zi r
# col_es%t_ssbef r
# lun_pp%itype r
# col_pp%nlevbed r
# col_pp%dz r
# urbanparams_vars%tk_wall r
# urbanparams_vars%tk_roof r
# urbanparams_vars%nlev_improad r
# urbanparams_vars%tk_improad r
# soilstate_vars%watsat_col r
# soilstate_vars%tkmg_col r
# soilstate_vars%tkdry_col r
# urbanparams_vars%cv_wall r
# urbanparams_vars%cv_roof r
# urbanparams_vars%cv_improad r
# soilstate_vars%csol_col r
# col_es%emg r
# col_pp%npfts r
# col_pp%pfti r
# veg_pp%landunit r
# veg_pp%topounit r
# veg_pp%gridcell r
# veg_pp%active r
# veg_ef%dlrad r
# top_af%lwrad r
# veg_ef%eflx_sh_grnd r
# veg_wf%qflx_evap_soi r
# col_ef%htvp r
# veg_ef%eflx_sh_snow r
# veg_wf%qflx_ev_snow r
# veg_ef%eflx_sh_soil r
# veg_wf%qflx_ev_soil r
# veg_ef%eflx_sh_h2osfc r
# veg_wf%qflx_ev_h2osfc r
# lun_pp%wtlunit_roof r
# lun_ef%eflx_wasteheat r
# lun_ef%eflx_heat_from_ac r
# lun_ef%eflx_traffic r
# veg_ef%eflx_lwrad_net r
# veg_wf%qflx_tran_veg r
# veg_ef%cgrnd r
# veg_pp%wtcol r
# solarabs_vars%sabg_patch r
# canopystate_vars%frac_veg_nosno_patch r
# solarabs_vars%sabg_snow_patch r
# solarabs_vars%sabg_soil_patch r
# solarabs_vars%sabg_lyr_patch r
# col_ef%eflx_bot r
# soilstate_vars%sucsat_col r
# soilstate_vars%bsw_col r
# Notebook::Write-Only
# col_ef%eflx_urban_ac w
# col_ef%eflx_urban_heat w
# col_ef%xmf_h2osfc w
# col_ef%eflx_fgr12 w
# col_ef%eflx_fgr w
# veg_ef%eflx_anthro w
# solarabs_vars%sabg_chk_patch w
# col_wf%qflx_h2osfc_to_ice w
# col_ef%eflx_h2osfc_to_snow w
# col_wf%qflx_snow_melt w
# col_ef%eflx_snomelt_u w
# col_ef%eflx_snomelt_r w
# Notebook::Read-Write
# lun_es%t_building rw
# col_es%fact rw
# col_es%c_h2osfc rw
# col_es%t_soisno rw
# col_es%t_h2osfc rw
# col_ef%eflx_building_heat rw
# col_es%hc_soisno rw
# col_es%hc_soi rw
# col_ws%bw rw
# soilstate_vars%thk_col rw
# col_es%t_grnd rw
# veg_ef%eflx_gnet rw
# veg_ef%eflx_wasteheat rw
# veg_ef%eflx_heat_from_ac rw
# veg_ef%eflx_traffic rw
# veg_ef%dgnetdt rw
# col_ws%frac_h2osfc rw
# col_ws%frac_sno_eff rw
# col_ws%h2osfc rw
# col_ws%snow_depth rw
# col_ws%h2osno rw
# col_ws%int_snow rw
# col_wf%qflx_snomelt rw
# col_ef%xmf rw
# col_wf%qflx_snofrz_lyr rw
# col_wf%qflx_snofrz rw
# col_wf%qflx_glcice_melt rw
# col_ef%imelt rw
# col_ws%h2osoi_ice rw
# col_ws%h2osoi_liq rw
# col_wf%qflx_glcice rw
# col_ef%eflx_snomelt rw
#
# Derived Type Analysis for laketemperature
# Notebook::Read-Only
# bounds%endc r
# bounds%begc r
# col_pp%snl r
# veg_pp%column r
# solarabs_vars%fsds_nir_d_patch r
# solarabs_vars%fsds_nir_i_patch r
# solarabs_vars%fsr_nir_d_patch r
# solarabs_vars%fsr_nir_i_patch r
# solarabs_vars%sabg_patch r
# col_pp%z_lake r
# lakestate_vars%ws_col r
# lakestate_vars%ks_col r
# col_es%t_grnd r
# col_pp%lakedepth r
# lakestate_vars%etal_col r
# col_pp%dz_lake r
# solarabs_vars%sabg_lyr_patch r
# col_pp%z r
# col_pp%dz r
# lakestate_vars%lake_raw_col r
# col_pp%zi r
# soilstate_vars%tksatu_col r
# soilstate_vars%tkmg_col r
# soilstate_vars%watsat_col r
# soilstate_vars%tkdry_col r
# soilstate_vars%csol_col r
# Notebook::Write-Only
# col_ws%frac_iceold w
# lakestate_vars%savedtke1_col w
# col_ef%eflx_snomelt w
# col_ef%imelt w
# Notebook::Read-Write
# col_es%hc_soisno rw
# col_es%hc_soi rw
# lakestate_vars%lakeresist_col rw
# veg_ef%eflx_gnet rw
# lakestate_vars%betaprime_col rw
# lakestate_vars%lake_icefrac_col rw
# col_es%t_lake rw
# col_es%t_soisno rw
# ch4_vars%grnd_ch4_cond_col rw
# col_ef%errsoi rw
# veg_ef%eflx_sh_tot rw
# veg_ef%eflx_sh_grnd rw
# veg_ef%eflx_soil_grnd rw
# lakestate_vars%lake_icethick_col rw
# col_wf%qflx_snomelt rw
# col_wf%qflx_snow_melt rw
# col_wf%qflx_snofrz_lyr rw
# col_ws%h2osno rw
# col_ws%snow_depth rw
# col_ws%h2osoi_ice rw
# col_ws%h2osoi_liq rw
# col_wf%qflx_snofrz rw

# %%
# Make sure physical properties types are read/written:
list_pp = ['veg_pp','lun_pp','col_pp','grc_pp','top_pp']

print("read_types:",read_types)
print("write_types:",write_types)

aggregated_elmtypes_list = []
for x in read_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)    
for x in write_types:
    dtype_inst = x.split('%')[0]
    if(dtype_inst not in aggregated_elmtypes_list):
        aggregated_elmtypes_list.append(dtype_inst)

# for l in list_pp:
#     aggregated_elmtypes_list.append(l)
print("list of global vars:",aggregated_elmtypes_list)
# Out:
# read_types: ['lun_pp%urbpoi', 'urbanparams_vars%t_building_max', 'urbanparams_vars%t_building_min', 'col_pp%snl', 'col_pp%itype', 'col_pp%landunit', 'bounds%begl', 'bounds%endl', 'bounds%begc', 'bounds%endc', 'col_pp%z', 'col_pp%zi', 'col_es%t_ssbef', 'lun_pp%itype', 'col_pp%nlevbed', 'col_pp%dz', 'urbanparams_vars%tk_wall', 'urbanparams_vars%tk_roof', 'urbanparams_vars%nlev_improad', 'urbanparams_vars%tk_improad', 'soilstate_vars%watsat_col', 'soilstate_vars%tkmg_col', 'soilstate_vars%tkdry_col', 'urbanparams_vars%cv_wall', 'urbanparams_vars%cv_roof', 'urbanparams_vars%cv_improad', 'soilstate_vars%csol_col', 'col_es%emg', 'col_pp%npfts', 'col_pp%pfti', 'veg_pp%landunit', 'veg_pp%topounit', 'veg_pp%gridcell', 'veg_pp%active', 'veg_ef%dlrad', 'top_af%lwrad', 'veg_ef%eflx_sh_grnd', 'veg_wf%qflx_evap_soi', 'col_ef%htvp', 'veg_ef%eflx_sh_snow', 'veg_wf%qflx_ev_snow', 'veg_ef%eflx_sh_soil', 'veg_wf%qflx_ev_soil', 'veg_ef%eflx_sh_h2osfc', 'veg_wf%qflx_ev_h2osfc', 'lun_pp%wtlunit_roof', 'lun_ef%eflx_wasteheat', 'lun_ef%eflx_heat_from_ac', 'lun_ef%eflx_traffic', 'veg_ef%eflx_lwrad_net', 'veg_wf%qflx_tran_veg', 'veg_ef%cgrnd', 'veg_pp%wtcol', 'solarabs_vars%sabg_patch', 'canopystate_vars%frac_veg_nosno_patch', 'solarabs_vars%sabg_snow_patch', 'solarabs_vars%sabg_soil_patch', 'solarabs_vars%sabg_lyr_patch', 'col_ef%eflx_bot', 'soilstate_vars%sucsat_col', 'soilstate_vars%bsw_col', 'bounds%endc', 'bounds%begc', 'col_pp%snl', 'veg_pp%column', 'solarabs_vars%fsds_nir_d_patch', 'solarabs_vars%fsds_nir_i_patch', 'solarabs_vars%fsr_nir_d_patch', 'solarabs_vars%fsr_nir_i_patch', 'solarabs_vars%sabg_patch', 'col_pp%z_lake', 'lakestate_vars%ws_col', 'lakestate_vars%ks_col', 'col_es%t_grnd', 'col_pp%lakedepth', 'lakestate_vars%etal_col', 'col_pp%dz_lake', 'solarabs_vars%sabg_lyr_patch', 'col_pp%z', 'col_pp%dz', 'lakestate_vars%lake_raw_col', 'col_pp%zi', 'soilstate_vars%tksatu_col', 'soilstate_vars%tkmg_col', 'soilstate_vars%watsat_col', 'soilstate_vars%tkdry_col', 'soilstate_vars%csol_col']
# write_types: ['col_ef%eflx_urban_ac', 'col_ef%eflx_urban_heat', 'col_ef%xmf_h2osfc', 'col_ef%eflx_fgr12', 'col_ef%eflx_fgr', 'veg_ef%eflx_anthro', 'solarabs_vars%sabg_chk_patch', 'col_wf%qflx_h2osfc_to_ice', 'col_ef%eflx_h2osfc_to_snow', 'col_wf%qflx_snow_melt', 'col_ef%eflx_snomelt_u', 'col_ef%eflx_snomelt_r', 'lun_es%t_building', 'col_es%fact', 'col_es%c_h2osfc', 'col_es%t_soisno', 'col_es%t_h2osfc', 'col_ef%eflx_building_heat', 'col_es%hc_soisno', 'col_es%hc_soi', 'col_ws%bw', 'soilstate_vars%thk_col', 'col_es%t_grnd', 'veg_ef%eflx_gnet', 'veg_ef%eflx_wasteheat', 'veg_ef%eflx_heat_from_ac', 'veg_ef%eflx_traffic', 'veg_ef%dgnetdt', 'col_ws%frac_h2osfc', 'col_ws%frac_sno_eff', 'col_ws%h2osfc', 'col_ws%snow_depth', 'col_ws%h2osno', 'col_ws%int_snow', 'col_wf%qflx_snomelt', 'col_ef%xmf', 'col_wf%qflx_snofrz_lyr', 'col_wf%qflx_snofrz', 'col_wf%qflx_glcice_melt', 'col_ef%imelt', 'col_ws%h2osoi_ice', 'col_ws%h2osoi_liq', 'col_wf%qflx_glcice', 'col_ef%eflx_snomelt', 'col_ws%frac_iceold', 'lakestate_vars%savedtke1_col', 'col_ef%eflx_snomelt', 'col_ef%imelt', 'col_es%hc_soisno', 'col_es%hc_soi', 'lakestate_vars%lakeresist_col', 'veg_ef%eflx_gnet', 'lakestate_vars%betaprime_col', 'lakestate_vars%lake_icefrac_col', 'col_es%t_lake', 'col_es%t_soisno', 'ch4_vars%grnd_ch4_cond_col', 'col_ef%errsoi', 'veg_ef%eflx_sh_tot', 'veg_ef%eflx_sh_grnd', 'veg_ef%eflx_soil_grnd', 'lakestate_vars%lake_icethick_col', 'col_wf%qflx_snomelt', 'col_wf%qflx_snow_melt', 'col_wf%qflx_snofrz_lyr', 'col_ws%h2osno', 'col_ws%snow_depth', 'col_ws%h2osoi_ice', 'col_ws%h2osoi_liq', 'col_wf%qflx_snofrz']
# list of global vars: ['lun_pp', 'urbanparams_vars', 'col_pp', 'bounds', 'col_es', 'soilstate_vars', 'veg_pp', 'veg_ef', 'top_af', 'veg_wf', 'col_ef', 'lun_ef', 'solarabs_vars', 'canopystate_vars', 'lakestate_vars', 'col_wf', 'lun_es', 'col_ws', 'ch4_vars']

# %%
from UnitTestforELM import set_active_variables
instance_to_user_type = {}
elm_inst_vars = {}
for type_name, dtype in type_dict.items():
    if('bounds' in type_name): 
        continue
    if(not dtype.instances):
        print(f"Warning: no instances found for {type_name}")
        cmd = f'grep -rin -E "^[[:space:]]*(type)[[:space:]]*\({type_name}" {ELM_SRC}/main/elm_instMod.F90'
        output = sp.getoutput(cmd)
        print(f"output: {output}")
        if(output):
            output = output.split('\n')
            if(len(output) > 1):
                print(f"Warning: multiple instances found for {type_name}")
                print(output)
                sys.exit(1)
            line = output[0]
            line = line.replace('::','')
            line = line.split(':')
            
            decl = line[1].strip()
            decl = decl.split()
            var = decl[1]
            new_inst = Variable(type_name,var,subgrid='?',ln=0,dim=0,declaration='elm_instMod')
            dtype.instances.append(new_inst)
            elm_inst_vars[var] = dtype
        else:
            print(f"Warning: no instances found for {type_name}")
    for instance in dtype.instances:
        instance_to_user_type[instance.name] = type_name

dtype_info_list = []
    
for s in sub_name_list:
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_r,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_w,dtype_info_list)
    set_active_variables(type_dict,instance_to_user_type,
                            subroutines[s].elmtype_rw,dtype_info_list)
    
print(dtype_info_list)
# Out:
# [['lun_pp', 'urbpoi', 'logical', '1D'], ['urbanparams_vars', 't_building_max', 'real', '1D'], ['urbanparams_vars', 't_building_min', 'real', '1D'], ['col_pp', 'snl', 'integer', '1D'], ['col_pp', 'itype', 'integer', '1D'], ['col_pp', 'landunit', 'integer', '1D'], ['col_pp', 'z', 'real', '2D'], ['col_pp', 'zi', 'real', '2D'], ['col_es', 't_ssbef', 'real', '2D'], ['lun_pp', 'itype', 'integer', '1D'], ['col_pp', 'nlevbed', 'integer', '1D'], ['col_pp', 'dz', 'real', '2D'], ['urbanparams_vars', 'tk_wall', 'real', '2D'], ['urbanparams_vars', 'tk_roof', 'real', '2D'], ['urbanparams_vars', 'nlev_improad', 'integer', '1D'], ['urbanparams_vars', 'tk_improad', 'real', '2D'], ['soilstate_vars', 'watsat_col', 'real', '2D'], ['soilstate_vars', 'tkmg_col', 'real', '2D'], ['soilstate_vars', 'tkdry_col', 'real', '2D'], ['urbanparams_vars', 'cv_wall', 'real', '2D'], ['urbanparams_vars', 'cv_roof', 'real', '2D'], ['urbanparams_vars', 'cv_improad', 'real', '2D'], ['soilstate_vars', 'csol_col', 'real', '2D'], ['col_es', 'emg', 'real', '1D'], ['col_pp', 'npfts', 'integer', '1D'], ['col_pp', 'pfti', 'integer', '1D'], ['veg_pp', 'landunit', 'integer', '1D'], ['veg_pp', 'topounit', 'integer', '1D'], ['veg_pp', 'gridcell', 'integer', '1D'], ['veg_pp', 'active', 'logical', '1D'], ['veg_ef', 'dlrad', 'real', '1D'], ['top_af', 'lwrad', 'real', '1D'], ['veg_ef', 'eflx_sh_grnd', 'real', '1D'], ['veg_wf', 'qflx_evap_soi', 'real', '1D'], ['col_ef', 'htvp', 'real', '1D'], ['veg_ef', 'eflx_sh_snow', 'real', '1D'], ['veg_wf', 'qflx_ev_snow', 'real', '1D'], ['veg_ef', 'eflx_sh_soil', 'real', '1D'], ['veg_wf', 'qflx_ev_soil', 'real', '1D'], ['veg_ef', 'eflx_sh_h2osfc', 'real', '1D'], ['veg_wf', 'qflx_ev_h2osfc', 'real', '1D'], ['lun_pp', 'wtlunit_roof', 'real', '1D'], ['lun_ef', 'eflx_wasteheat', 'real', '1D'], ['lun_ef', 'eflx_heat_from_ac', 'real', '1D'], ['lun_ef', 'eflx_traffic', 'real', '1D'], ['veg_ef', 'eflx_lwrad_net', 'real', '1D'], ['veg_wf', 'qflx_tran_veg', 'real', '1D'], ['veg_ef', 'cgrnd', 'real', '1D'], ['veg_pp', 'wtcol', 'real', '1D'], ['solarabs_vars', 'sabg_patch', 'real', '1D'], ['canopystate_vars', 'frac_veg_nosno_patch', 'integer', '1D'], ['solarabs_vars', 'sabg_snow_patch', 'real', '1D'], ['solarabs_vars', 'sabg_soil_patch', 'real', '1D'], ['solarabs_vars', 'sabg_lyr_patch', 'real', '2D'], ['col_ef', 'eflx_bot', 'real', '1D'], ['soilstate_vars', 'sucsat_col', 'real', '2D'], ['soilstate_vars', 'bsw_col', 'real', '2D'], ['col_ef', 'eflx_urban_ac', 'real', '1D'], ['col_ef', 'eflx_urban_heat', 'real', '1D'], ['col_ef', 'xmf_h2osfc', 'real', '1D'], ['col_ef', 'eflx_fgr12', 'real', '1D'], ['col_ef', 'eflx_fgr', 'real', '2D'], ['veg_ef', 'eflx_anthro', 'real', '1D'], ['solarabs_vars', 'sabg_chk_patch', 'real', '1D'], ['col_wf', 'qflx_h2osfc_to_ice', 'real', '1D'], ['col_ef', 'eflx_h2osfc_to_snow', 'real', '1D'], ['col_wf', 'qflx_snow_melt', 'real', '1D'], ['col_ef', 'eflx_snomelt_u', 'real', '1D'], ['col_ef', 'eflx_snomelt_r', 'real', '1D'], ['lun_es', 't_building', 'real', '1D'], ['col_es', 'fact', 'real', '2D'], ['col_es', 'c_h2osfc', 'real', '1D'], ['col_es', 't_soisno', 'real', '2D'], ['col_es', 't_h2osfc', 'real', '1D'], ['col_ef', 'eflx_building_heat', 'real', '1D'], ['col_es', 'hc_soisno', 'real', '1D'], ['col_es', 'hc_soi', 'real', '1D'], ['col_ws', 'bw', 'real', '2D'], ['soilstate_vars', 'thk_col', 'real', '2D'], ['col_es', 't_grnd', 'real', '1D'], ['veg_ef', 'eflx_gnet', 'real', '1D'], ['veg_ef', 'eflx_wasteheat', 'real', '1D'], ['veg_ef', 'eflx_heat_from_ac', 'real', '1D'], ['veg_ef', 'eflx_traffic', 'real', '1D'], ['veg_ef', 'dgnetdt', 'real', '1D'], ['col_ws', 'frac_h2osfc', 'real', '1D'], ['col_ws', 'frac_sno_eff', 'real', '1D'], ['col_ws', 'h2osfc', 'real', '1D'], ['col_ws', 'snow_depth', 'real', '1D'], ['col_ws', 'h2osno', 'real', '1D'], ['col_ws', 'int_snow', 'real', '1D'], ['col_wf', 'qflx_snomelt', 'real', '1D'], ['col_ef', 'xmf', 'real', '1D'], ['col_wf', 'qflx_snofrz_lyr', 'real', '2D'], ['col_wf', 'qflx_snofrz', 'real', '1D'],  ...

# %%
for sub in subroutines.values():
    tree = sub.calltree[2:]
    sub.analyze_calltree(tree,case_dir)
# Out:
# soiltemperature
# |---->soilthermprop
# |---->computegroundheatfluxandderiv
# |---->computeheatdifffluxandfactor
# |---->solvetemperature
# |---->|---->setrhsvec
# |---->|---->|---->setrhsvec_snow
# |---->|---->|---->|---->setrhsvec_snowurban
# |---->|---->|---->|---->|---->setrhsvec_snowurbannonroad
# |---->|---->|---->|---->|---->setrhsvec_snowurbanroad
# |---->|---->|---->|---->setrhsvec_snownonurban
# |---->|---->|---->setrhsvec_standingsurfacewater
# |---->|---->|---->setrhsvec_soil
# |---->|---->|---->|---->setrhsvec_soilurban
# |---->|---->|---->|---->|---->setrhsvec_soilurbannonroad
# |---->|---->|---->|---->|---->setrhsvec_soilurbanroad
# |---->|---->|---->|---->setrhsvec_soilnonurban
# |---->|---->|---->|---->setrhsvec_soil_standingsurfacewater
# |---->|---->setmatrix
# |---->|---->|---->setmatrix_snow
# |---->|---->|---->|---->setmatrix_snowurban
# |---->|---->|---->|---->|---->setmatrix_snowurbannonroad
# |---->|---->|---->|---->|---->setmatrix_snowurbanroad
# |---->|---->|---->|---->setmatrix_snownonurban
# |---->|---->|---->setmatrix_snow_soil
# |---->|---->|---->|---->setmatrix_snow_soilurban
# |---->|---->|---->|---->|---->setmatrix_snow_soilurbannonroad
# |---->|---->|---->|---->|---->setmatrix_snow_soilurbanroad
# |---->|---->|---->|---->setmatrix_snow_soilnonurban
# |---->|---->|---->setmatrix_soil
# |---->|---->|---->|---->setmatrix_soilurban
# |---->|---->|---->|---->|---->setmatrix_soilurbannonroad
# |---->|---->|---->|---->|---->setmatrix_soilurbanroad
# |---->|---->|---->|---->setmatrix_soilnonurban
# |---->|---->|---->setmatrix_soil_snow
# |---->|---->|---->|---->setmatrix_soil_snowurban
# |---->|---->|---->|---->|---->setmatrix_soil_snowurbannonroad
# |---->|---->|---->|---->|---->setmatrix_soil_snowurbanroad
# |---->|---->|---->|---->setmatrix_soil_snownonurban
# |---->|---->|---->setmatrix_standingsurfacewater
# |---->|---->|---->setmatrix_standingsurfacewater_soil
# |---->|---->|---->setmatrix_soil_standingsurfacewater
# |---->|---->|---->assemblematrixfromsubmatrices
# |---->|---->banddiagonal
# |---->|---->|---->dgbsv
# |---->phasechangeh2osfc
# |---->phasechange_beta
# laketemperature
# |---->soilthermprop_lake
# |---->tridiagonal_sr
# |---->phasechange_lake

# %%
subname = 'laketemperature' 
sub:Subroutine = main_sub_dict[subname]
for child_sub in sub.child_Subroutine.values():
    print(child_sub.name)
    for subcall in child_sub.subroutine_call:
        print(subcall.subname)
        print(subcall.args)
# Out:
# soilthermprop_lake
# laketemperature
# [bounds => bounds, num_lakec => num_lakec, filter_lakec => filter_lakec, cv => tk, tk => cv, tktopsoillay => tktopsoillay, soilstate_vars => soilstate_vars]
# tridiagonal_sr
# laketemperature
# [bounds => bounds, jtop => jtop, numf => num_lakec, filter => filter_lakec, a => a, b => b, c => c1, r => r, u => tx]
# phasechange_lake
# laketemperature
# [bounds => bounds, num_lakec => num_lakec, filter_lakec => filter_lakec, cv => cv, cv_lake => cv_lake, lhabs => lhabs, energyflux_vars => energyflux_vars, lakestate_vars => lakestate_vars, dtime => dtime]
